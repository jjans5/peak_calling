# %%
mamba activate scatac_fragment_tools

# %%
# === Chromosome sizes mapping ===
declare -A chrom_sizes
chrom_sizes["Gorilla"]="/cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/genomes/Gorilla_gorilla.gorGor4.dna.toplevel.chrom.sizes"
chrom_sizes["Chimpanzee"]="/cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/genomes/Pan_troglodytes.Pan_tro_3.0.dna.toplevel.chrom.sizes"
chrom_sizes["Bonobo"]="/cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/genomes/Pan_paniscus.panpan1.1.dna.toplevel.chrom.sizes"
chrom_sizes["Macaque"]="/cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/genomes/Macaca_mulatta.Mmul_10.dna.toplevel.chrom.sizes"
chrom_sizes["Human"]="/cluster/home/jjanssens/jjans/analysis/cerebellum/genomes_new/homo_sapiens/hg38.chrom.sizes"
chrom_sizes["Marmoset"]="/cluster/home/jjanssens/jjans/analysis/cerebellum/genomes_new/homo_sapiens/hg38.chrom.sizes"

# === Loop through species ===
for species in "Gorilla" "Chimpanzee" "Bonobo" "Macaque" "Human"; do
  input_frag="lifted_fragments/${species}_enterocytes.hg38.fragments_par.tsv.gz"
  chrom_file="${chrom_sizes[$species]}"
  chrom_file="/cluster/home/jjanssens/jjans/analysis/cerebellum/genomes_new/homo_sapiens/hg38.chrom.sizes"
  output_bw="bigwigs/${species}_enterocytes.hg38.cov.bw"

  if [[ -s "$input_frag" && -s "$chrom_file" ]]; then
    echo "🎯 Converting $species to bigWig..."
    scatac_fragment_tools bigwig \
      -i "$input_frag" \
      -c "$chrom_file" \
      -o "$output_bw" \
      -n 
    echo "✅ Done: $output_bw"
  else
    echo "⚠️  Missing input or chrom sizes for $species — skipping"
  fi
done
# Out:
# 🎯 Converting Gorilla to bigWig...
# ✅ Done: bigwigs/Gorilla_enterocytes.hg38.cov.bw
# 🎯 Converting Chimpanzee to bigWig...

# %%
# === Chromosome sizes mapping ===
declare -A chrom_sizes
chrom_sizes["Gorilla"]="/cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/genomes/Gorilla_gorilla.gorGor4.dna.toplevel.chrom.sizes"
chrom_sizes["Chimpanzee"]="/cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/genomes/Pan_troglodytes.Pan_tro_3.0.dna.toplevel.chrom.sizes"
chrom_sizes["Bonobo"]="/cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/genomes/Pan_paniscus.panpan1.1.dna.toplevel.chrom.sizes"
chrom_sizes["Macaque"]="/cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/genomes/Macaca_mulatta.Mmul_10.dna.toplevel.chrom.sizes"
chrom_sizes["Human"]="/cluster/home/jjanssens/jjans/analysis/cerebellum/genomes_new/homo_sapiens/hg38.chrom.sizes"
chrom_sizes["Marmoset"]="/cluster/home/jjanssens/jjans/analysis/cerebellum/genomes_new/homo_sapiens/hg38.chrom.sizes"

# === Loop through species ===
for species in "Marmoset"; do
  input_frag="lifted_fragments/${species}_enterocytes.hg38.fragments_par.tsv.gz"
  chrom_file="${chrom_sizes[$species]}"
  chrom_file="/cluster/home/jjanssens/jjans/analysis/cerebellum/genomes_new/homo_sapiens/hg38.chrom.sizes"
  output_bw="bigwigs/${species}_enterocytes.hg38.cov.bw"

  if [[ -s "$input_frag" && -s "$chrom_file" ]]; then
    echo "🎯 Converting $species to bigWig..."
    scatac_fragment_tools bigwig \
      -i "$input_frag" \
      -c "$chrom_file" \
      -o "$output_bw" \
      -n
    echo "✅ Done: $output_bw"
  else
    echo "⚠️  Missing input or chrom sizes for $species — skipping"
  fi
done
# Out:
# 🎯 Converting Marmoset to bigWig...
# ✅ Done: bigwigs/Marmoset_enterocytes.hg38.cov.bw

# %%
# === Loop through species ===
for species in "Human"; do
  input_frag="fragment_files/Human_enterocytes.fragments.tsv.gz"
  chrom_file="/cluster/home/jjanssens/jjans/analysis/cerebellum/genomes_new/homo_sapiens/hg38.chrom.sizes"
  output_bw="bigwigs/${species}_enterocytes.hg38.bw"

  if [[ -s "$input_frag" && -s "$chrom_file" ]]; then
    echo "🎯 Converting $species to bigWig..."
    scatac_fragment_tools bigwig \
      -i "$input_frag" \
      -c "$chrom_file" \
      -o "$output_bw" \
      -x 
    echo "✅ Done: $output_bw"
  else
    echo "⚠️  Missing input or chrom sizes for $species — skipping"
  fi
done
# Out:
# 🎯 Converting Human to bigWig...
# ✅ Done: bigwigs/Human_enterocytes.hg38.bw

# %%
# === Loop through species ===
for species in "Marmoset"; do
  input_frag="fragment_files/Human_enterocytes.fragments.tsv.gz"
  chrom_file="/cluster/home/jjanssens/jjans/analysis/cerebellum/genomes_new/homo_sapiens/hg38.chrom.sizes"
  output_bw="bigwigs/${species}_enterocytes.hg38.bw"

  if [[ -s "$input_frag" && -s "$chrom_file" ]]; then
    echo "🎯 Converting $species to bigWig..."
    scatac_fragment_tools bigwig \
      -i "$input_frag" \
      -c "$chrom_file" \
      -o "$output_bw" \
      -x 
    echo "✅ Done: $output_bw"
  else
    echo "⚠️  Missing input or chrom sizes for $species — skipping"
  fi
done

# %%
ls -lah lifted_fragments
# Out:
# total 1.4G
# drwxr-x--- 3 jjanssens jjanssens-group 4.0K Jun 18 00:17 .
# drwxr-x--- 6 jjanssens jjanssens-group 4.0K Jun 18 00:16 ..
# drwxr-x--- 2 jjanssens jjanssens-group 4.0K Jun 17 16:51 .ipynb_checkpoints
# -rw-r----- 1 jjanssens jjanssens-group 1.9K Jun 17 18:09 Bonobo.log
# -rw-r----- 1 jjanssens jjanssens-group 549M Jun 17 18:08 Bonobo_enterocytes.hg38.fragments_par.tsv.gz
# -rw-r----- 1 jjanssens jjanssens-group  40M Jun 17 18:09 Bonobo_enterocytes.hg38.fragments_par.unmapped.tsv.gz
# -rw-r----- 1 jjanssens jjanssens-group 2.0K Jun 17 17:49 Chimpanzee.log
# -rw-r----- 1 jjanssens jjanssens-group 527M Jun 17 17:49 Chimpanzee_enterocytes.hg38.fragments_par.tsv.gz
# -rw-r----- 1 jjanssens jjanssens-group  35M Jun 17 17:49 Chimpanzee_enterocytes.hg38.fragments_par.unmapped.tsv.gz
# -rw-r----- 1 jjanssens jjanssens-group 1.9K Jun 17 18:15 Gorilla.log
# -rw-r----- 1 jjanssens jjanssens-group  69M Jun 17 18:15 Gorilla_enterocytes.hg38.fragments_par.tsv.gz
# ...

# %%
ls lifted_fragments
# Out:
# Bonobo.log
# Bonobo_enterocytes.hg38.fragments.tsv.gz
# Bonobo_enterocytes.hg38.fragments.unmapped.tsv.gz
# Bonobo_enterocytes.hg38.fragments_par.tsv.gz
# Bonobo_enterocytes.hg38.fragments_par.unmapped.tsv.gz
# Chimpanzee.log
# Chimpanzee_enterocytes.hg38.fragments_par.tsv.gz
# Chimpanzee_enterocytes.hg38.fragments_par.unmapped.tsv.gz
# Gorilla.log
# Gorilla_enterocytes.hg38.fragments_par.tsv.gz
# Gorilla_enterocytes.hg38.fragments_par.unmapped.tsv.gz
# Macaque.log
# Macaque_enterocytes.hg38.fragments_par.tsv.gz
# Macaque_enterocytes.hg38.fragments_par.unmapped.tsv.gz

# %%
ls /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/genomes/Gorilla_gorilla.gorGor4.dna.toplevel.chrom.sizes

genomes_dict = {
    "Gorilla": "genomes/Gorilla_gorilla.gorGor4.dna.toplevel.chrom.sizes",
    "Chimpanzee": "genomes/Pan_troglodytes.Pan_tro_3.0.dna.toplevel.chrom.sizes",
    "Bonobo": "genomes/Pan_paniscus.panpan1.1.dna.toplevel.chrom.sizes",
    "Macaque": "genomes/Macaca_mulatta.Mmul_10.dna.toplevel.chrom.sizes",
    "Human": "/cluster/home/jjanssens/jjans/analysis/cerebellum/genomes_new/homo_sapiens/hg38.chrom.sizes"
}


scatac_fragment_tools bigwig -i lifted_fragments/Bonobo_enterocytes.hg38.fragments_par.tsv.gz -c <CHROM_SIZES_FILENAME> -o bigwigs/Bonobo_enterocytes.hg38.bw -x True

# %%
# Out:
# /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/genomes/Gorilla_gorilla.gorGor4.dna.toplevel.chrom.sizes

# %%
pwd
# Out:
# /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/dl_models/enterocytes_v0

# %%
scatac_fragment_tools bigwig -i lifted_fragments/Bonobo_enterocytes.hg38.fragments_par.tsv.gz -c <CHROM_SIZES_FILENAME> -o <BIGWIG_FILENAME> -x True
