# %% [markdown]
# # Complete Fragment Processing Workflow
#
# This notebook performs the complete workflow for processing scATAC-seq fragments across multiple species:
# 1. **Link fragments** to organized folder structure (by cell type)
# 2. **Liftover fragments** to human genome (hg38) using parallel implementation
# 3. **Convert fragments** to coverage bigWig files
#
# ---

# %% [markdown]
# ## Setup and Configuration
#
# Define species, auto-detect cell types, and configure file paths.

# %%
# Activate the genomes environment for liftover operations
mamba activate genomes

# %%
ls /cluster/work/treutlein/jjans/data/intestine/nhp_atlas/genomes/chain_files
# Out:
# calJac1ToCalJac4.over.chain   hg38ToHg19.over.chain
# calJac1ToHg19.over.chain      hg38ToMm10.over.chain
# calJac4ToCalJac1.over.chain   hg38ToPanPan2.over.chain
# calJac4ToHg38.over.chain      hg38ToPanTro3.over.chain
# danRer11ToHg38.over.chain     hg38ToPanTro5.over.chain
# danRer7ToDanRer11.over.chain  hg38ToRheMac10.over.chain
# gorGor4ToHg38.over.chain      mm10ToHg38.over.chain
# hg16ToHg38.over.chain	      obsolete
# hg17ToHg38.over.chain	      panPan2ToHg38.over.chain
# hg18ToHg38.over.chain	      panTro3ToHg38.over.chain
# hg19ToCalJac1.over.chain      panTro5ToHg38.over.chain
# hg19ToHg38.over.chain	      panTro6ToHg38.over.chain
# hg38ToCalJac4.over.chain      rheMac10ToHg38.over.chain
# hg38ToGorGor4.over.chain

# %%
# Define species to process
SPECIES=("Human" "Gorilla" "Chimpanzee" "Bonobo" "Macaque" "Marmoset")

# Base directories
BASE_DIR="/cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac"
CHAIN_DIR="${BASE_DIR}/genomes/chains"
MARMOSET_CHAIN_DIR="/cluster/work/treutlein/jjans/data/intestine/nhp_atlas/genomes/chain_files"
CHROM_SIZES="/cluster/home/jjanssens/jjans/analysis/cerebellum/genomes_new/homo_sapiens/hg38.chrom.sizes"

# Chain file mapping
declare -A CHAIN_FILES
CHAIN_FILES["Gorilla"]="${CHAIN_DIR}/gorGor4ToHg38.over.chain.gz"
CHAIN_FILES["Chimpanzee"]="${CHAIN_DIR}/panTro5ToHg38.over.chain.gz"
CHAIN_FILES["Bonobo"]="${CHAIN_DIR}/panPan2ToHg38.over.chain.gz"
CHAIN_FILES["Macaque"]="${CHAIN_DIR}/rheMac10ToHg38.over.chain.gz"
CHAIN_FILES["Marmoset_step1"]="${MARMOSET_CHAIN_DIR}/calJac1ToCalJac4.over.chain"
CHAIN_FILES["Marmoset_step2"]="${MARMOSET_CHAIN_DIR}/calJac4ToHg38.over.chain"

echo "✅ Configuration loaded"
# Out:
# ✅ Configuration loaded

# %% [markdown]
# ### Auto-detect Available Cell Types
#
# Scan all species directories to find available cell types.

# %%
# Auto-detect cell types from available fragment files across all species
echo "🔍 Scanning for available cell types across all species..."
echo ""

# Create associative array to store unique cell types
declare -A UNIQUE_CELL_TYPES

# Scan each species directory
for species in "${SPECIES[@]}"; do
    species_dir="${BASE_DIR}/consensus_peak_calling_${species}/pseudobulk_bed_files"
    
    if [[ -d "$species_dir" ]]; then
        echo "📂 Scanning ${species}..."
        
        # Find all .fragments.tsv.gz files and extract cell type names
        while IFS= read -r file; do
            if [[ -n "$file" ]]; then
                # Extract cell type name (remove .fragments.tsv.gz extension)
                cell_type=$(basename "$file" .fragments.tsv.gz)
                UNIQUE_CELL_TYPES["$cell_type"]=1
                echo "   ✓ Found: ${cell_type}"
            fi
        done < <(find "$species_dir" -maxdepth 1 -name "*.fragments.tsv.gz" -type f 2>/dev/null)
    else
        echo "⚠️  Directory not found for ${species}: $species_dir"
    fi
    echo ""
done

# Convert associative array keys to regular array
CELL_TYPES=($(echo "${!UNIQUE_CELL_TYPES[@]}" | tr ' ' '\n' | sort))

# Display detected cell types
echo "================================"
echo "📋 Detected Cell Types (${#CELL_TYPES[@]} total):"
echo "================================"
for cell_type in "${CELL_TYPES[@]}"; do
    echo "  • $cell_type"
done
echo ""

# Create a summary of which cell types are present in which species
echo "================================"
echo "📊 Cell Type × Species Matrix:"
echo "================================"
for cell_type in "${CELL_TYPES[@]}"; do
    echo ""
    echo "📌 ${cell_type}:"
    for species in "${SPECIES[@]}"; do
        file_path="${BASE_DIR}/consensus_peak_calling_${species}/pseudobulk_bed_files/${cell_type}.fragments.tsv.gz"
        if [[ -f "$file_path" ]]; then
            echo "   ✅ ${species}"
        else
            echo "   ❌ ${species} (not available)"
        fi
    done
done

echo ""
echo "✅ Cell type detection completed"
# Out:
# 🔍 Scanning for available cell types across all species...
#
# 📂 Scanning Human...
#    ✓ Found: Adipocytes
#    ✓ Found: BEST4+_cells
#    ✓ Found: Crypt_Fibroblasts_WNT2B+
#    ✓ Found: Colonocytes
#    ✓ Found: Enterocytes
#    ✓ Found: Specialized_Fibroblasts_VCAM1+
#    ✓ Found: Villus_Fibroblasts_WNT5B+
#    ✓ Found: T_cells
#    ✓ Found: Specialized_Fibroblasts_SYNM+
#    ✓ Found: Monocytes
#    ✓ Found: Plasma_B_cells
#    ✓ Found: Stem_cells
#    ✓ Found: Tuft_cells
#    ✓ Found: TA_cells
#    ✓ Found: Specialized_Fibroblasts_RSPO2_3+
#    ✓ Found: Specialized_Fibroblasts_RSPO3+_only
#    ✓ Found: Pericytes
#    ✓ Found: Specialized_Fibroblasts_KCNN3+
#    ✓ Found: ILCs
#    ✓ Found: Lymphatic_ECs
#    ✓ Found: Goblet_cells
#    ✓ Found: Macrophages
#    ✓ Found: ICCs
#    ✓ Found: Myofibroblasts
#    ✓ Found: Naive_B_cells
#    ✓ Found: EECs
#    ✓ Found: Enteric_glia
#    ✓ Found: Mast_cells
#    ✓ Found: ECs
#    ✓ Found: Enteric_neurons
#    ✓ Found: MUC6+_cells
#    ✓ Found: Paneth_cells
#
# 📂 Scanning Gorilla...
#    ✓ Found: Specialized_Fibroblasts_RALYL+
#    ✓ Found: Specialized_Fibroblasts_RSPO2_3+
#    ✓ Found: Specialized_Fibroblasts_SYNM+
#    ✓ Found: Specialized_Fibroblasts_RSPO3+_only
#    ✓ Found: Stem_cells
#    ✓ Found: Colonocytes
#    ✓ Found: T_cells
#    ✓ Found: Neutrophils
#    ✓ Found: Villus_Fibroblasts_WNT5B+
#    ✓ Found: Enteric_neurons
#    ✓ Found: Mesothelial_cells
#    ✓ Found: TA_cells
#    ✓ Found: EECs
#    ✓ Found: Crypt_Fibroblasts_WNT2B+
#    ✓ Found: Paneth_cells
#    ✓ Found: Naive_B_cells
#    ✓ Found: Eosinophils
#    ✓ Found: Mast_cells
#    ✓ Found: Specialized_Fibroblasts_KCNN3+
#    ✓ Found: Enterocytes
#    ✓ Found: Myofibroblasts
#    ✓ Found: Pericytes
#    ✓ Found: Macrophages
#    ✓ Found: Lymphatic_ECs
#    ✓ Found: Plasma_B_cells
#    ✓ Found: ICCs
#    ✓ Found: Goblet_cells
#    ✓ Found: ECs
#    ✓ Found: Specialized_Fibroblasts_ADAMTS16+
#    ✓ Found: Enteric_glia
#    ✓ Found: Tuft_cells
#    ✓ Found: BEST4+_cells
#    ✓ Found: Adipocytes
#
# 📂 Scanning Chimpanzee...
#    ✓ Found: Adipocytes
#    ✓ Found: Crypt_Fibroblasts_WNT2B+
#    ✓ Found: ECs
#    ✓ Found: Lymphatic_ECs
#    ✓ Found: Mesothelial_cells
#    ✓ Found: ICCs
#    ✓ Found: Myofibroblasts
#    ✓ Found: Enteric_glia
#    ✓ Found: Mast_cells
#    ✓ Found: Specialized_Fibroblasts_KCNN3+
#    ✓ Found: Naive_B_cells
#    ✓ Found: Specialized_Fibroblasts_SYNM+
#    ✓ Found: Pericytes
#    ✓ Found: T_cells
#    ✓ Found: Specialized_Fibroblasts_VCAM1+
#    ✓ Found: Specialized_Fibroblasts_RSPO3+_only
#    ✓ Found: Specialized_Fibroblasts_RSPO2_3+
#    ✓ Found: Villus_Fibroblasts_WNT5B+
#    ✓ Found: EECs
#    ✓ Found: Enterocytes
#    ✓ Found: Goblet_cells
#    ✓ Found: Macrophages
#    ✓ Found: Monocytes
#    ✓ Found: Paneth_cells
#    ✓ Found: Plasma_B_cells
#    ✓ Found: Specialized_Fibroblasts_RALYL+
#    ✓ Found: Stem_cells
#    ✓ Found: TA_cells
#    ✓ Found: Tuft_cells
#    ✓ Found: Colonocytes
#    ✓ Found: BEST4+_cells
#    ✓ Found: MUC6+_cells
#
# 📂 Scanning Bonobo...
#    ✓ Found: T_cells
#    ✓ Found: Specialized_Fibroblasts_VCAM1+
#    ✓ Found: Tuft_cells
#    ✓ Found: TA_cells
#    ✓ Found: Colonocytes
#    ✓ Found: Villus_Fibroblasts_WNT5B+
#    ✓ Found: Stem_cells
#    ✓ Found: Mast_cells
#    ✓ Found: Myofibroblasts
#    ✓ Found: Crypt_Fibroblasts_WNT2B+
#    ✓ Found: Eosinophils
#    ✓ Found: Enteric_neurons
#    ✓ Found: Adipocytes
#    ✓ Found: BEST4+_cells
#    ✓ Found: Enterocytes
#    ✓ Found: ICCs
#    ✓ Found: Specialized_Fibroblasts_KCNN3+
#    ✓ Found: Goblet_cells
#    ✓ Found: Neutrophils
#    ✓ Found: Enteric_glia
#    ✓ Found: ECs
#    ✓ Found: Monocytes
#    ✓ Found: EECs
#    ✓ Found: Mesothelial_cells
#    ✓ Found: Naive_B_cells
#    ✓ Found: Macrophages
#    ✓ Found: Pericytes
#    ✓ Found: Specialized_Fibroblasts_RSPO3+_only
#    ✓ Found: Lymphatic_ECs
#    ✓ Found: Plasma_B_cells
#    ✓ Found: MUC6+_cells
#    ✓ Found: Paneth_cells
#    ✓ Found: Specialized_Fibroblasts_RSPO2_3+
#    ✓ Found: Specialized_Fibroblasts_SYNM+
#    ✓ Found: MARCO+_Lymphatic_ECs
#
# 📂 Scanning Macaque...
#    ✓ Found: Specialized_Fibroblasts_VCAM1+
#    ✓ Found: T_cells
#    ✓ Found: Stem_cells
#    ✓ Found: TA_cells
#    ✓ Found: Tuft_cells
#    ✓ Found: Villus_Fibroblasts_WNT5B+
#    ✓ Found: BEST4+_cells
#    ✓ Found: Adipocytes
#    ✓ Found: Enteric_glia
#    ✓ Found: Myofibroblasts
#    ✓ Found: Mesothelial_cells
#    ✓ Found: ICCs
#    ✓ Found: Plasma_B_cells
#    ✓ Found: Specialized_Fibroblasts_SYNM+
#    ✓ Found: EECs
#    ✓ Found: Monocytes
#    ✓ Found: Lymphatic_ECs
#    ✓ Found: Enterocytes
#    ✓ Found: Paneth_cells
#    ✓ Found: Naive_B_cells
#    ✓ Found: Crypt_Fibroblasts_WNT2B+
#    ✓ Found: Goblet_cells
#    ✓ Found: Pericytes
#    ✓ Found: Specialized_Fibroblasts_RSPO3+_only
#    ✓ Found: Specialized_Fibroblasts_KCNN3+
#    ✓ Found: Specialized_Fibroblasts_RSPO2_3+
#    ✓ Found: Specialized_Fibroblasts_RALYL+
#    ✓ Found: Macrophages
#    ✓ Found: Specialized_Fibroblasts_PCDH9+
#    ✓ Found: ECs
#    ✓ Found: Colonocytes
#    ✓ Found: Enteric_neurons
#
# 📂 Scanning Marmoset...
#    ✓ Found: Enterocytes
#    ✓ Found: Enteric_neurons
#    ✓ Found: EECs
#    ✓ Found: ICCs
#    ✓ Found: Goblet-like_cells
#    ✓ Found: Lymphatic_ECs
#    ✓ Found: Goblet_cells
#    ✓ Found: Macrophages
#    ✓ Found: Enteric_glia
#    ✓ Found: Pericytes
#    ✓ Found: Myofibroblasts
#    ✓ Found: Specialized_Fibroblasts_KCNN3+
#    ✓ Found: ECs
#    ✓ Found: BEST4+_cells
#    ✓ Found: Crypt_Fibroblasts_WNT2B+
#    ✓ Found: Specialized_Fibroblasts_RSPO2_3+
#    ✓ Found: Specialized_Fibroblasts_RSPO3+_only
#    ✓ Found: Specialized_Fibroblasts_SYNM+
#    ✓ Found: T_cells
#    ✓ Found: TA_cells
#    ✓ Found: Tuft_cells
#    ✓ Found: Villus_Fibroblasts_WNT5B+
#    ✓ Found: Adipocytes
#    ✓ Found: Mast_cells
#    ✓ Found: Mesothelial_cells
#    ✓ Found: Monocytes
#    ✓ Found: Naive_B_cells
#    ✓ Found: Paneth_cells
#    ✓ Found: Plasma_B_cells
#    ✓ Found: RBP2_high_cells
#    ✓ Found: Specialized_Fibroblasts_VCAM1+
#    ✓ Found: Stem_cells
#    ✓ Found: Colonocytes
#
# ================================
# 📋 Detected Cell Types (41 total):
# ================================
#   • Adipocytes
#   • BEST4+_cells
#   • Colonocytes
#   • Crypt_Fibroblasts_WNT2B+
#   • ECs
#   • EECs
#   • Enteric_glia
#   • Enteric_neurons
#   • Enterocytes
#   • Eosinophils
#   • Goblet-like_cells
#   • Goblet_cells
#   • ICCs
#   • ILCs
#   • Lymphatic_ECs
#   • MARCO+_Lymphatic_ECs
#   • MUC6+_cells
#   • Macrophages
#   • Mast_cells
#   • Mesothelial_cells
#   • Monocytes
#   • Myofibroblasts
#   • Naive_B_cells
#   • Neutrophils
#   • Paneth_cells
#   • Pericytes
#   • Plasma_B_cells
#   • RBP2_high_cells
#   • Specialized_Fibroblasts_ADAMTS16+
#   • Specialized_Fibroblasts_KCNN3+
#   • Specialized_Fibroblasts_PCDH9+
#   • Specialized_Fibroblasts_RALYL+
#   • Specialized_Fibroblasts_RSPO2_3+
#   • Specialized_Fibroblasts_RSPO3+_only
#   • Specialized_Fibroblasts_SYNM+
#   • Specialized_Fibroblasts_VCAM1+
#   • Stem_cells
#   • TA_cells
#   • T_cells
#   • Tuft_cells
#   • Villus_Fibroblasts_WNT5B+
#
# ================================
# 📊 Cell Type × Species Matrix:
# ================================
#
# 📌 Adipocytes:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 BEST4+_cells:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Colonocytes:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Crypt_Fibroblasts_WNT2B+:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 ECs:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 EECs:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Enteric_glia:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Enteric_neurons:
#    ✅ Human
#    ✅ Gorilla
#    ❌ Chimpanzee (not available)
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Enterocytes:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Eosinophils:
#    ❌ Human (not available)
#    ✅ Gorilla
#    ❌ Chimpanzee (not available)
#    ✅ Bonobo
#    ❌ Macaque (not available)
#    ❌ Marmoset (not available)
#
# 📌 Goblet-like_cells:
#    ❌ Human (not available)
#    ❌ Gorilla (not available)
#    ❌ Chimpanzee (not available)
#    ❌ Bonobo (not available)
#    ❌ Macaque (not available)
#    ✅ Marmoset
#
# 📌 Goblet_cells:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 ICCs:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 ILCs:
#    ✅ Human
#    ❌ Gorilla (not available)
#    ❌ Chimpanzee (not available)
#    ❌ Bonobo (not available)
#    ❌ Macaque (not available)
#    ❌ Marmoset (not available)
#
# 📌 Lymphatic_ECs:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 MARCO+_Lymphatic_ECs:
#    ❌ Human (not available)
#    ❌ Gorilla (not available)
#    ❌ Chimpanzee (not available)
#    ✅ Bonobo
#    ❌ Macaque (not available)
#    ❌ Marmoset (not available)
#
# 📌 MUC6+_cells:
#    ✅ Human
#    ❌ Gorilla (not available)
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ❌ Macaque (not available)
#    ❌ Marmoset (not available)
#
# 📌 Macrophages:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Mast_cells:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ❌ Macaque (not available)
#    ✅ Marmoset
#
# 📌 Mesothelial_cells:
#    ❌ Human (not available)
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Monocytes:
#    ✅ Human
#    ❌ Gorilla (not available)
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Myofibroblasts:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Naive_B_cells:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Neutrophils:
#    ❌ Human (not available)
#    ✅ Gorilla
#    ❌ Chimpanzee (not available)
#    ✅ Bonobo
#    ❌ Macaque (not available)
#    ❌ Marmoset (not available)
#
# 📌 Paneth_cells:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Pericytes:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Plasma_B_cells:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 RBP2_high_cells:
#    ❌ Human (not available)
#    ❌ Gorilla (not available)
#    ❌ Chimpanzee (not available)
#    ❌ Bonobo (not available)
#    ❌ Macaque (not available)
#    ✅ Marmoset
#
# 📌 Specialized_Fibroblasts_ADAMTS16+:
#    ❌ Human (not available)
#    ✅ Gorilla
#    ❌ Chimpanzee (not available)
#    ❌ Bonobo (not available)
#    ❌ Macaque (not available)
#    ❌ Marmoset (not available)
#
# 📌 Specialized_Fibroblasts_KCNN3+:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Specialized_Fibroblasts_PCDH9+:
#    ❌ Human (not available)
#    ❌ Gorilla (not available)
#    ❌ Chimpanzee (not available)
#    ❌ Bonobo (not available)
#    ✅ Macaque
#    ❌ Marmoset (not available)
#
# 📌 Specialized_Fibroblasts_RALYL+:
#    ❌ Human (not available)
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ❌ Bonobo (not available)
#    ✅ Macaque
#    ❌ Marmoset (not available)
#
# 📌 Specialized_Fibroblasts_RSPO2_3+:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Specialized_Fibroblasts_RSPO3+_only:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Specialized_Fibroblasts_SYNM+:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Specialized_Fibroblasts_VCAM1+:
#    ✅ Human
#    ❌ Gorilla (not available)
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Stem_cells:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 TA_cells:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 T_cells:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Tuft_cells:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# 📌 Villus_Fibroblasts_WNT5B+:
#    ✅ Human
#    ✅ Gorilla
#    ✅ Chimpanzee
#    ✅ Bonobo
#    ✅ Macaque
#    ✅ Marmoset
#
# ✅ Cell type detection completed

# %% [markdown]
# ---
# ## Step 1: Link Fragment Files
#
# Create organized directory structure and link fragment files by cell type.

# %%
# Create directory structure for each cell type
for cell_type in "${CELL_TYPES[@]}"; do
    cell_type_lower=$(echo "$cell_type" | tr '[:upper:]' '[:lower:]')
    mkdir -p "fragment_files/${cell_type_lower}"
    echo "📁 Created directory: fragment_files/${cell_type_lower}"
done

echo "✅ Directory structure created"
# Out:
# 📁 Created directory: fragment_files/adipocytes
# 📁 Created directory: fragment_files/best4+_cells
# 📁 Created directory: fragment_files/colonocytes
# 📁 Created directory: fragment_files/crypt_fibroblasts_wnt2b+
# 📁 Created directory: fragment_files/ecs
# 📁 Created directory: fragment_files/eecs
# 📁 Created directory: fragment_files/enteric_glia
# 📁 Created directory: fragment_files/enteric_neurons
# 📁 Created directory: fragment_files/enterocytes
# 📁 Created directory: fragment_files/eosinophils
# 📁 Created directory: fragment_files/goblet-like_cells
# 📁 Created directory: fragment_files/goblet_cells
# 📁 Created directory: fragment_files/iccs
# 📁 Created directory: fragment_files/ilcs
# 📁 Created directory: fragment_files/lymphatic_ecs
# 📁 Created directory: fragment_files/marco+_lymphatic_ecs
# 📁 Created directory: fragment_files/muc6+_cells
# 📁 Created directory: fragment_files/macrophages
# 📁 Created directory: fragment_files/mast_cells
# 📁 Created directory: fragment_files/mesothelial_cells
# 📁 Created directory: fragment_files/monocytes
# 📁 Created directory: fragment_files/myofibroblasts
# 📁 Created directory: fragment_files/naive_b_cells
# 📁 Created directory: fragment_files/neutrophils
# 📁 Created directory: fragment_files/paneth_cells
# 📁 Created directory: fragment_files/pericytes
# 📁 Created directory: fragment_files/plasma_b_cells
# 📁 Created directory: fragment_files/rbp2_high_cells
# 📁 Created directory: fragment_files/specialized_fibroblasts_adamts16+
# 📁 Created directory: fragment_files/specialized_fibroblasts_kcnn3+
# 📁 Created directory: fragment_files/specialized_fibroblasts_pcdh9+
# 📁 Created directory: fragment_files/specialized_fibroblasts_ralyl+
# 📁 Created directory: fragment_files/specialized_fibroblasts_rspo2_3+
# 📁 Created directory: fragment_files/specialized_fibroblasts_rspo3+_only
# 📁 Created directory: fragment_files/specialized_fibroblasts_synm+
# 📁 Created directory: fragment_files/specialized_fibroblasts_vcam1+
# 📁 Created directory: fragment_files/stem_cells
# 📁 Created directory: fragment_files/ta_cells
# 📁 Created directory: fragment_files/t_cells
# 📁 Created directory: fragment_files/tuft_cells
# 📁 Created directory: fragment_files/villus_fibroblasts_wnt5b+
# ✅ Directory structure created

# %%
# Link fragment files for each species and cell type
for cell_type in "${CELL_TYPES[@]}"; do
    cell_type_lower=$(echo "$cell_type" | tr '[:upper:]' '[:lower:]')
    
    for species in "${SPECIES[@]}"; do
        species_lower=$(echo "$species" | tr '[:upper:]' '[:lower:]')
        
        # Source file path
        source_file="${BASE_DIR}/consensus_peak_calling_${species}/pseudobulk_bed_files/${cell_type}.fragments.tsv.gz"
        
        # Target link path
        target_link="fragment_files/${cell_type_lower}/${species_lower}_${cell_type_lower}.fragments.tsv.gz"
        
        # Create symlink if source exists
        if [[ -f "$source_file" ]]; then
            ln -sf "$source_file" "$target_link"
            echo "🔗 Linked: ${species} ${cell_type}"
        else
            echo "⚠️  Source not found: ${species} ${cell_type}"
        fi
    done
done

echo ""
echo "✅ All fragment files linked"
# Out:
# 🔗 Linked: Human Adipocytes
# 🔗 Linked: Gorilla Adipocytes
# 🔗 Linked: Chimpanzee Adipocytes
# 🔗 Linked: Bonobo Adipocytes
# 🔗 Linked: Macaque Adipocytes
# 🔗 Linked: Marmoset Adipocytes
# 🔗 Linked: Human BEST4+_cells
# 🔗 Linked: Gorilla BEST4+_cells
# 🔗 Linked: Chimpanzee BEST4+_cells
# 🔗 Linked: Bonobo BEST4+_cells
# 🔗 Linked: Macaque BEST4+_cells
# 🔗 Linked: Marmoset BEST4+_cells
# 🔗 Linked: Human Colonocytes
# 🔗 Linked: Gorilla Colonocytes
# 🔗 Linked: Chimpanzee Colonocytes
# 🔗 Linked: Bonobo Colonocytes
# 🔗 Linked: Macaque Colonocytes
# 🔗 Linked: Marmoset Colonocytes
# 🔗 Linked: Human Crypt_Fibroblasts_WNT2B+
# 🔗 Linked: Gorilla Crypt_Fibroblasts_WNT2B+
# 🔗 Linked: Chimpanzee Crypt_Fibroblasts_WNT2B+
# 🔗 Linked: Bonobo Crypt_Fibroblasts_WNT2B+
# 🔗 Linked: Macaque Crypt_Fibroblasts_WNT2B+
# 🔗 Linked: Marmoset Crypt_Fibroblasts_WNT2B+
# 🔗 Linked: Human ECs
# 🔗 Linked: Gorilla ECs
# 🔗 Linked: Chimpanzee ECs
# 🔗 Linked: Bonobo ECs
# 🔗 Linked: Macaque ECs
# 🔗 Linked: Marmoset ECs
# 🔗 Linked: Human EECs
# 🔗 Linked: Gorilla EECs
# 🔗 Linked: Chimpanzee EECs
# 🔗 Linked: Bonobo EECs
# 🔗 Linked: Macaque EECs
# 🔗 Linked: Marmoset EECs
# 🔗 Linked: Human Enteric_glia
# 🔗 Linked: Gorilla Enteric_glia
# 🔗 Linked: Chimpanzee Enteric_glia
# 🔗 Linked: Bonobo Enteric_glia
# 🔗 Linked: Macaque Enteric_glia
# 🔗 Linked: Marmoset Enteric_glia
# 🔗 Linked: Human Enteric_neurons
# 🔗 Linked: Gorilla Enteric_neurons
# ⚠️  Source not found: Chimpanzee Enteric_neurons
# 🔗 Linked: Bonobo Enteric_neurons
# 🔗 Linked: Macaque Enteric_neurons
# 🔗 Linked: Marmoset Enteric_neurons
# 🔗 Linked: Human Enterocytes
# 🔗 Linked: Gorilla Enterocytes
# 🔗 Linked: Chimpanzee Enterocytes
# 🔗 Linked: Bonobo Enterocytes
# 🔗 Linked: Macaque Enterocytes
# 🔗 Linked: Marmoset Enterocytes
# ⚠️  Source not found: Human Eosinophils
# 🔗 Linked: Gorilla Eosinophils
# ⚠️  Source not found: Chimpanzee Eosinophils
# 🔗 Linked: Bonobo Eosinophils
# ⚠️  Source not found: Macaque Eosinophils
# ⚠️  Source not found: Marmoset Eosinophils
# ⚠️  Source not found: Human Goblet-like_cells
# ⚠️  Source not found: Gorilla Goblet-like_cells
# ⚠️  Source not found: Chimpanzee Goblet-like_cells
# ⚠️  Source not found: Bonobo Goblet-like_cells
# ⚠️  Source not found: Macaque Goblet-like_cells
# 🔗 Linked: Marmoset Goblet-like_cells
# 🔗 Linked: Human Goblet_cells
# 🔗 Linked: Gorilla Goblet_cells
# 🔗 Linked: Chimpanzee Goblet_cells
# 🔗 Linked: Bonobo Goblet_cells
# 🔗 Linked: Macaque Goblet_cells
# 🔗 Linked: Marmoset Goblet_cells
# 🔗 Linked: Human ICCs
# 🔗 Linked: Gorilla ICCs
# 🔗 Linked: Chimpanzee ICCs
# 🔗 Linked: Bonobo ICCs
# 🔗 Linked: Macaque ICCs
# 🔗 Linked: Marmoset ICCs
# 🔗 Linked: Human ILCs
# ⚠️  Source not found: Gorilla ILCs
# ⚠️  Source not found: Chimpanzee ILCs
# ⚠️  Source not found: Bonobo ILCs
# ⚠️  Source not found: Macaque ILCs
# ⚠️  Source not found: Marmoset ILCs
# 🔗 Linked: Human Lymphatic_ECs
# 🔗 Linked: Gorilla Lymphatic_ECs
# 🔗 Linked: Chimpanzee Lymphatic_ECs
# 🔗 Linked: Bonobo Lymphatic_ECs
# 🔗 Linked: Macaque Lymphatic_ECs
# 🔗 Linked: Marmoset Lymphatic_ECs
# ⚠️  Source not found: Human MARCO+_Lymphatic_ECs
# ⚠️  Source not found: Gorilla MARCO+_Lymphatic_ECs
# ⚠️  Source not found: Chimpanzee MARCO+_Lymphatic_ECs
# 🔗 Linked: Bonobo MARCO+_Lymphatic_ECs
# ⚠️  Source not found: Macaque MARCO+_Lymphatic_ECs
# ⚠️  Source not found: Marmoset MARCO+_Lymphatic_ECs
# 🔗 Linked: Human MUC6+_cells
# ⚠️  Source not found: Gorilla MUC6+_cells
# 🔗 Linked: Chimpanzee MUC6+_cells
# 🔗 Linked: Bonobo MUC6+_cells
# ⚠️  Source not found: Macaque MUC6+_cells
# ⚠️  Source not found: Marmoset MUC6+_cells
# 🔗 Linked: Human Macrophages
# 🔗 Linked: Gorilla Macrophages
# 🔗 Linked: Chimpanzee Macrophages
# 🔗 Linked: Bonobo Macrophages
# 🔗 Linked: Macaque Macrophages
# 🔗 Linked: Marmoset Macrophages
# 🔗 Linked: Human Mast_cells
# 🔗 Linked: Gorilla Mast_cells
# 🔗 Linked: Chimpanzee Mast_cells
# 🔗 Linked: Bonobo Mast_cells
# ⚠️  Source not found: Macaque Mast_cells
# 🔗 Linked: Marmoset Mast_cells
# ⚠️  Source not found: Human Mesothelial_cells
# 🔗 Linked: Gorilla Mesothelial_cells
# 🔗 Linked: Chimpanzee Mesothelial_cells
# 🔗 Linked: Bonobo Mesothelial_cells
# 🔗 Linked: Macaque Mesothelial_cells
# 🔗 Linked: Marmoset Mesothelial_cells
# 🔗 Linked: Human Monocytes
# ⚠️  Source not found: Gorilla Monocytes
# 🔗 Linked: Chimpanzee Monocytes
# 🔗 Linked: Bonobo Monocytes
# 🔗 Linked: Macaque Monocytes
# 🔗 Linked: Marmoset Monocytes
# 🔗 Linked: Human Myofibroblasts
# 🔗 Linked: Gorilla Myofibroblasts
# 🔗 Linked: Chimpanzee Myofibroblasts
# 🔗 Linked: Bonobo Myofibroblasts
# 🔗 Linked: Macaque Myofibroblasts
# 🔗 Linked: Marmoset Myofibroblasts
# 🔗 Linked: Human Naive_B_cells
# 🔗 Linked: Gorilla Naive_B_cells
# 🔗 Linked: Chimpanzee Naive_B_cells
# 🔗 Linked: Bonobo Naive_B_cells
# 🔗 Linked: Macaque Naive_B_cells
# 🔗 Linked: Marmoset Naive_B_cells
# ⚠️  Source not found: Human Neutrophils
# 🔗 Linked: Gorilla Neutrophils
# ⚠️  Source not found: Chimpanzee Neutrophils
# 🔗 Linked: Bonobo Neutrophils
# ⚠️  Source not found: Macaque Neutrophils
# ⚠️  Source not found: Marmoset Neutrophils
# 🔗 Linked: Human Paneth_cells
# 🔗 Linked: Gorilla Paneth_cells
# 🔗 Linked: Chimpanzee Paneth_cells
# 🔗 Linked: Bonobo Paneth_cells
# 🔗 Linked: Macaque Paneth_cells
# 🔗 Linked: Marmoset Paneth_cells
# 🔗 Linked: Human Pericytes
# 🔗 Linked: Gorilla Pericytes
# 🔗 Linked: Chimpanzee Pericytes
# 🔗 Linked: Bonobo Pericytes
# 🔗 Linked: Macaque Pericytes
# 🔗 Linked: Marmoset Pericytes
# 🔗 Linked: Human Plasma_B_cells
# 🔗 Linked: Gorilla Plasma_B_cells
# 🔗 Linked: Chimpanzee Plasma_B_cells
# 🔗 Linked: Bonobo Plasma_B_cells
# 🔗 Linked: Macaque Plasma_B_cells
# 🔗 Linked: Marmoset Plasma_B_cells
# ⚠️  Source not found: Human RBP2_high_cells
# ⚠️  Source not found: Gorilla RBP2_high_cells
# ⚠️  Source not found: Chimpanzee RBP2_high_cells
# ⚠️  Source not found: Bonobo RBP2_high_cells
# ⚠️  Source not found: Macaque RBP2_high_cells
# 🔗 Linked: Marmoset RBP2_high_cells
# ⚠️  Source not found: Human Specialized_Fibroblasts_ADAMTS16+
# 🔗 Linked: Gorilla Specialized_Fibroblasts_ADAMTS16+
# ⚠️  Source not found: Chimpanzee Specialized_Fibroblasts_ADAMTS16+
# ⚠️  Source not found: Bonobo Specialized_Fibroblasts_ADAMTS16+
# ⚠️  Source not found: Macaque Specialized_Fibroblasts_ADAMTS16+
# ⚠️  Source not found: Marmoset Specialized_Fibroblasts_ADAMTS16+
# 🔗 Linked: Human Specialized_Fibroblasts_KCNN3+
# 🔗 Linked: Gorilla Specialized_Fibroblasts_KCNN3+
# 🔗 Linked: Chimpanzee Specialized_Fibroblasts_KCNN3+
# 🔗 Linked: Bonobo Specialized_Fibroblasts_KCNN3+
# 🔗 Linked: Macaque Specialized_Fibroblasts_KCNN3+
# 🔗 Linked: Marmoset Specialized_Fibroblasts_KCNN3+
# ⚠️  Source not found: Human Specialized_Fibroblasts_PCDH9+
# ⚠️  Source not found: Gorilla Specialized_Fibroblasts_PCDH9+
# ⚠️  Source not found: Chimpanzee Specialized_Fibroblasts_PCDH9+
# ⚠️  Source not found: Bonobo Specialized_Fibroblasts_PCDH9+
# 🔗 Linked: Macaque Specialized_Fibroblasts_PCDH9+
# ⚠️  Source not found: Marmoset Specialized_Fibroblasts_PCDH9+
# ⚠️  Source not found: Human Specialized_Fibroblasts_RALYL+
# 🔗 Linked: Gorilla Specialized_Fibroblasts_RALYL+
# 🔗 Linked: Chimpanzee Specialized_Fibroblasts_RALYL+
# ⚠️  Source not found: Bonobo Specialized_Fibroblasts_RALYL+
# 🔗 Linked: Macaque Specialized_Fibroblasts_RALYL+
# ⚠️  Source not found: Marmoset Specialized_Fibroblasts_RALYL+
# 🔗 Linked: Human Specialized_Fibroblasts_RSPO2_3+
# 🔗 Linked: Gorilla Specialized_Fibroblasts_RSPO2_3+
# 🔗 Linked: Chimpanzee Specialized_Fibroblasts_RSPO2_3+
# 🔗 Linked: Bonobo Specialized_Fibroblasts_RSPO2_3+
# 🔗 Linked: Macaque Specialized_Fibroblasts_RSPO2_3+
# 🔗 Linked: Marmoset Specialized_Fibroblasts_RSPO2_3+
# 🔗 Linked: Human Specialized_Fibroblasts_RSPO3+_only
# 🔗 Linked: Gorilla Specialized_Fibroblasts_RSPO3+_only
# 🔗 Linked: Chimpanzee Specialized_Fibroblasts_RSPO3+_only
# 🔗 Linked: Bonobo Specialized_Fibroblasts_RSPO3+_only
# 🔗 Linked: Macaque Specialized_Fibroblasts_RSPO3+_only
# 🔗 Linked: Marmoset Specialized_Fibroblasts_RSPO3+_only
# 🔗 Linked: Human Specialized_Fibroblasts_SYNM+
# 🔗 Linked: Gorilla Specialized_Fibroblasts_SYNM+
# 🔗 Linked: Chimpanzee Specialized_Fibroblasts_SYNM+
# 🔗 Linked: Bonobo Specialized_Fibroblasts_SYNM+
# 🔗 Linked: Macaque Specialized_Fibroblasts_SYNM+
# 🔗 Linked: Marmoset Specialized_Fibroblasts_SYNM+
# 🔗 Linked: Human Specialized_Fibroblasts_VCAM1+
# ⚠️  Source not found: Gorilla Specialized_Fibroblasts_VCAM1+
# 🔗 Linked: Chimpanzee Specialized_Fibroblasts_VCAM1+
# 🔗 Linked: Bonobo Specialized_Fibroblasts_VCAM1+
# 🔗 Linked: Macaque Specialized_Fibroblasts_VCAM1+
# 🔗 Linked: Marmoset Specialized_Fibroblasts_VCAM1+
# 🔗 Linked: Human Stem_cells
# 🔗 Linked: Gorilla Stem_cells
# 🔗 Linked: Chimpanzee Stem_cells
# 🔗 Linked: Bonobo Stem_cells
# 🔗 Linked: Macaque Stem_cells
# 🔗 Linked: Marmoset Stem_cells
# 🔗 Linked: Human TA_cells
# 🔗 Linked: Gorilla TA_cells
# 🔗 Linked: Chimpanzee TA_cells
# 🔗 Linked: Bonobo TA_cells
# 🔗 Linked: Macaque TA_cells
# 🔗 Linked: Marmoset TA_cells
# 🔗 Linked: Human T_cells
# 🔗 Linked: Gorilla T_cells
# 🔗 Linked: Chimpanzee T_cells
# 🔗 Linked: Bonobo T_cells
# 🔗 Linked: Macaque T_cells
# 🔗 Linked: Marmoset T_cells
# 🔗 Linked: Human Tuft_cells
# 🔗 Linked: Gorilla Tuft_cells
# 🔗 Linked: Chimpanzee Tuft_cells
# 🔗 Linked: Bonobo Tuft_cells
# 🔗 Linked: Macaque Tuft_cells
# 🔗 Linked: Marmoset Tuft_cells
# 🔗 Linked: Human Villus_Fibroblasts_WNT5B+
# 🔗 Linked: Gorilla Villus_Fibroblasts_WNT5B+
# 🔗 Linked: Chimpanzee Villus_Fibroblasts_WNT5B+
# 🔗 Linked: Bonobo Villus_Fibroblasts_WNT5B+
# 🔗 Linked: Macaque Villus_Fibroblasts_WNT5B+
# 🔗 Linked: Marmoset Villus_Fibroblasts_WNT5B+
#
# ✅ All fragment files linked

# %%
# Verify linked files
for cell_type in "${CELL_TYPES[@]}"; do
    cell_type_lower=$(echo "$cell_type" | tr '[:upper:]' '[:lower:]')
    echo "\n📂 Fragment files for ${cell_type}:"
    ls -lh "fragment_files/${cell_type_lower}/"
done
# Out:
# \n📂 Fragment files for Adipocytes:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 147 Nov  4 18:37 bonobo_adipocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Adipocytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 151 Nov  4 18:37 chimpanzee_adipocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Adipocytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 gorilla_adipocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Adipocytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 146 Nov  4 18:37 human_adipocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Adipocytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 macaque_adipocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Adipocytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 149 Nov  4 18:37 marmoset_adipocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Adipocytes.fragments.tsv.gz
# \n📂 Fragment files for BEST4+_cells:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 149 Nov  4 18:37 bonobo_best4+_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/BEST4+_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 153 Nov  4 18:37 chimpanzee_best4+_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/BEST4+_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 150 Nov  4 18:37 gorilla_best4+_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/BEST4+_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 human_best4+_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/BEST4+_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 150 Nov  4 18:37 macaque_best4+_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/BEST4+_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 151 Nov  4 18:37 marmoset_best4+_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/BEST4+_cells.fragments.tsv.gz
# \n📂 Fragment files for Colonocytes:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 bonobo_colonocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Colonocytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 152 Nov  4 18:37 chimpanzee_colonocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Colonocytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 149 Nov  4 18:37 gorilla_colonocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Colonocytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 147 Nov  4 18:37 human_colonocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Colonocytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 149 Nov  4 18:37 macaque_colonocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Colonocytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 150 Nov  4 18:37 marmoset_colonocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Colonocytes.fragments.tsv.gz
# \n📂 Fragment files for Crypt_Fibroblasts_WNT2B+:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 161 Nov  4 18:37 bonobo_crypt_fibroblasts_wnt2b+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Crypt_Fibroblasts_WNT2B+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 165 Nov  4 18:37 chimpanzee_crypt_fibroblasts_wnt2b+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Crypt_Fibroblasts_WNT2B+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 162 Nov  4 18:37 gorilla_crypt_fibroblasts_wnt2b+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Crypt_Fibroblasts_WNT2B+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 160 Nov  4 18:37 human_crypt_fibroblasts_wnt2b+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Crypt_Fibroblasts_WNT2B+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 162 Nov  4 18:37 macaque_crypt_fibroblasts_wnt2b+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Crypt_Fibroblasts_WNT2B+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 163 Nov  4 18:37 marmoset_crypt_fibroblasts_wnt2b+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Crypt_Fibroblasts_WNT2B+.fragments.tsv.gz
# \n📂 Fragment files for ECs:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 140 Nov  4 18:37 bonobo_ecs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/ECs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 144 Nov  4 18:37 chimpanzee_ecs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/ECs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 141 Nov  4 18:37 gorilla_ecs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/ECs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 139 Nov  4 18:37 human_ecs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/ECs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 141 Nov  4 18:37 macaque_ecs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/ECs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 142 Nov  4 18:37 marmoset_ecs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/ECs.fragments.tsv.gz
# \n📂 Fragment files for EECs:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 141 Nov  4 18:37 bonobo_eecs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/EECs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 145 Nov  4 18:37 chimpanzee_eecs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/EECs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 142 Nov  4 18:37 gorilla_eecs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/EECs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 140 Nov  4 18:37 human_eecs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/EECs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 142 Nov  4 18:37 macaque_eecs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/EECs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 143 Nov  4 18:37 marmoset_eecs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/EECs.fragments.tsv.gz
# \n📂 Fragment files for Enteric_glia:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 149 Nov  4 18:37 bonobo_enteric_glia.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Enteric_glia.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 153 Nov  4 18:37 chimpanzee_enteric_glia.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Enteric_glia.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 150 Nov  4 18:37 gorilla_enteric_glia.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Enteric_glia.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 human_enteric_glia.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Enteric_glia.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 150 Nov  4 18:37 macaque_enteric_glia.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Enteric_glia.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 151 Nov  4 18:37 marmoset_enteric_glia.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Enteric_glia.fragments.tsv.gz
# \n📂 Fragment files for Enteric_neurons:
# total 20K
# lrwxrwxrwx 1 jjanssens jjanssens-group 152 Nov  4 18:37 bonobo_enteric_neurons.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Enteric_neurons.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 153 Nov  4 18:37 gorilla_enteric_neurons.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Enteric_neurons.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 151 Nov  4 18:37 human_enteric_neurons.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Enteric_neurons.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 153 Nov  4 18:37 macaque_enteric_neurons.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Enteric_neurons.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 154 Nov  4 18:37 marmoset_enteric_neurons.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Enteric_neurons.fragments.tsv.gz
# \n📂 Fragment files for Enterocytes:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 bonobo_enterocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Enterocytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 152 Nov  4 18:37 chimpanzee_enterocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Enterocytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 149 Nov  4 18:37 gorilla_enterocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Enterocytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 147 Nov  4 18:37 human_enterocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Enterocytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 149 Nov  4 18:37 macaque_enterocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Enterocytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 150 Nov  4 18:37 marmoset_enterocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Enterocytes.fragments.tsv.gz
# \n📂 Fragment files for Eosinophils:
# total 8.0K
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 bonobo_eosinophils.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Eosinophils.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 149 Nov  4 18:37 gorilla_eosinophils.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Eosinophils.fragments.tsv.gz
# \n📂 Fragment files for Goblet-like_cells:
# total 4.0K
# lrwxrwxrwx 1 jjanssens jjanssens-group 156 Nov  4 18:37 marmoset_goblet-like_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Goblet-like_cells.fragments.tsv.gz
# \n📂 Fragment files for Goblet_cells:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 149 Nov  4 18:37 bonobo_goblet_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Goblet_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 153 Nov  4 18:37 chimpanzee_goblet_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Goblet_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 150 Nov  4 18:37 gorilla_goblet_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Goblet_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 human_goblet_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Goblet_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 150 Nov  4 18:37 macaque_goblet_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Goblet_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 151 Nov  4 18:37 marmoset_goblet_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Goblet_cells.fragments.tsv.gz
# \n📂 Fragment files for ICCs:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 141 Nov  4 18:37 bonobo_iccs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/ICCs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 145 Nov  4 18:37 chimpanzee_iccs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/ICCs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 142 Nov  4 18:37 gorilla_iccs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/ICCs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 140 Nov  4 18:37 human_iccs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/ICCs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 142 Nov  4 18:37 macaque_iccs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/ICCs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 143 Nov  4 18:37 marmoset_iccs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/ICCs.fragments.tsv.gz
# \n📂 Fragment files for ILCs:
# total 4.0K
# lrwxrwxrwx 1 jjanssens jjanssens-group 140 Nov  4 18:37 human_ilcs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/ILCs.fragments.tsv.gz
# \n📂 Fragment files for Lymphatic_ECs:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 150 Nov  4 18:37 bonobo_lymphatic_ecs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Lymphatic_ECs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 154 Nov  4 18:37 chimpanzee_lymphatic_ecs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Lymphatic_ECs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 151 Nov  4 18:37 gorilla_lymphatic_ecs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Lymphatic_ECs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 149 Nov  4 18:37 human_lymphatic_ecs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Lymphatic_ECs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 151 Nov  4 18:37 macaque_lymphatic_ecs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Lymphatic_ECs.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 152 Nov  4 18:37 marmoset_lymphatic_ecs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Lymphatic_ECs.fragments.tsv.gz
# \n📂 Fragment files for MARCO+_Lymphatic_ECs:
# total 4.0K
# lrwxrwxrwx 1 jjanssens jjanssens-group 157 Nov  4 18:37 bonobo_marco+_lymphatic_ecs.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/MARCO+_Lymphatic_ECs.fragments.tsv.gz
# \n📂 Fragment files for MUC6+_cells:
# total 12K
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 bonobo_muc6+_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/MUC6+_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 152 Nov  4 18:37 chimpanzee_muc6+_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/MUC6+_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 147 Nov  4 18:37 human_muc6+_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/MUC6+_cells.fragments.tsv.gz
# \n📂 Fragment files for Macrophages:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 bonobo_macrophages.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Macrophages.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 152 Nov  4 18:37 chimpanzee_macrophages.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Macrophages.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 149 Nov  4 18:37 gorilla_macrophages.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Macrophages.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 147 Nov  4 18:37 human_macrophages.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Macrophages.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 149 Nov  4 18:37 macaque_macrophages.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Macrophages.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 150 Nov  4 18:37 marmoset_macrophages.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Macrophages.fragments.tsv.gz
# \n📂 Fragment files for Mast_cells:
# total 20K
# lrwxrwxrwx 1 jjanssens jjanssens-group 147 Nov  4 18:37 bonobo_mast_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Mast_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 151 Nov  4 18:37 chimpanzee_mast_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Mast_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 gorilla_mast_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Mast_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 146 Nov  4 18:37 human_mast_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Mast_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 149 Nov  4 18:37 marmoset_mast_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Mast_cells.fragments.tsv.gz
# \n📂 Fragment files for Mesothelial_cells:
# total 20K
# lrwxrwxrwx 1 jjanssens jjanssens-group 154 Nov  4 18:37 bonobo_mesothelial_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Mesothelial_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 158 Nov  4 18:37 chimpanzee_mesothelial_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Mesothelial_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 155 Nov  4 18:37 gorilla_mesothelial_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Mesothelial_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 155 Nov  4 18:37 macaque_mesothelial_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Mesothelial_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 156 Nov  4 18:37 marmoset_mesothelial_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Mesothelial_cells.fragments.tsv.gz
# \n📂 Fragment files for Monocytes:
# total 20K
# lrwxrwxrwx 1 jjanssens jjanssens-group 146 Nov  4 18:37 bonobo_monocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Monocytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 150 Nov  4 18:37 chimpanzee_monocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Monocytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 145 Nov  4 18:37 human_monocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Monocytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 147 Nov  4 18:37 macaque_monocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Monocytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 marmoset_monocytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Monocytes.fragments.tsv.gz
# \n📂 Fragment files for Myofibroblasts:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 151 Nov  4 18:37 bonobo_myofibroblasts.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Myofibroblasts.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 155 Nov  4 18:37 chimpanzee_myofibroblasts.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Myofibroblasts.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 152 Nov  4 18:37 gorilla_myofibroblasts.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Myofibroblasts.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 150 Nov  4 18:37 human_myofibroblasts.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Myofibroblasts.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 152 Nov  4 18:37 macaque_myofibroblasts.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Myofibroblasts.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 153 Nov  4 18:37 marmoset_myofibroblasts.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Myofibroblasts.fragments.tsv.gz
# \n📂 Fragment files for Naive_B_cells:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 150 Nov  4 18:37 bonobo_naive_b_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Naive_B_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 154 Nov  4 18:37 chimpanzee_naive_b_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Naive_B_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 151 Nov  4 18:37 gorilla_naive_b_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Naive_B_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 149 Nov  4 18:37 human_naive_b_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Naive_B_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 151 Nov  4 18:37 macaque_naive_b_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Naive_B_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 152 Nov  4 18:37 marmoset_naive_b_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Naive_B_cells.fragments.tsv.gz
# \n📂 Fragment files for Neutrophils:
# total 8.0K
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 bonobo_neutrophils.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Neutrophils.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 149 Nov  4 18:37 gorilla_neutrophils.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Neutrophils.fragments.tsv.gz
# \n📂 Fragment files for Paneth_cells:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 149 Nov  4 18:37 bonobo_paneth_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Paneth_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 153 Nov  4 18:37 chimpanzee_paneth_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Paneth_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 150 Nov  4 18:37 gorilla_paneth_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Paneth_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 human_paneth_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Paneth_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 150 Nov  4 18:37 macaque_paneth_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Paneth_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 151 Nov  4 18:37 marmoset_paneth_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Paneth_cells.fragments.tsv.gz
# \n📂 Fragment files for Pericytes:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 146 Nov  4 18:37 bonobo_pericytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Pericytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 150 Nov  4 18:37 chimpanzee_pericytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Pericytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 147 Nov  4 18:37 gorilla_pericytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Pericytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 145 Nov  4 18:37 human_pericytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Pericytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 147 Nov  4 18:37 macaque_pericytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Pericytes.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 marmoset_pericytes.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Pericytes.fragments.tsv.gz
# \n📂 Fragment files for Plasma_B_cells:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 151 Nov  4 18:37 bonobo_plasma_b_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Plasma_B_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 155 Nov  4 18:37 chimpanzee_plasma_b_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Plasma_B_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 152 Nov  4 18:37 gorilla_plasma_b_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Plasma_B_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 150 Nov  4 18:37 human_plasma_b_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Plasma_B_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 152 Nov  4 18:37 macaque_plasma_b_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Plasma_B_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 153 Nov  4 18:37 marmoset_plasma_b_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Plasma_B_cells.fragments.tsv.gz
# \n📂 Fragment files for RBP2_high_cells:
# total 4.0K
# lrwxrwxrwx 1 jjanssens jjanssens-group 154 Nov  4 18:37 marmoset_rbp2_high_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/RBP2_high_cells.fragments.tsv.gz
# \n📂 Fragment files for Specialized_Fibroblasts_ADAMTS16+:
# total 4.0K
# lrwxrwxrwx 1 jjanssens jjanssens-group 171 Nov  4 18:37 gorilla_specialized_fibroblasts_adamts16+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Specialized_Fibroblasts_ADAMTS16+.fragments.tsv.gz
# \n📂 Fragment files for Specialized_Fibroblasts_KCNN3+:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 167 Nov  4 18:37 bonobo_specialized_fibroblasts_kcnn3+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Specialized_Fibroblasts_KCNN3+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 171 Nov  4 18:37 chimpanzee_specialized_fibroblasts_kcnn3+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Specialized_Fibroblasts_KCNN3+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 168 Nov  4 18:37 gorilla_specialized_fibroblasts_kcnn3+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Specialized_Fibroblasts_KCNN3+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 166 Nov  4 18:37 human_specialized_fibroblasts_kcnn3+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Specialized_Fibroblasts_KCNN3+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 168 Nov  4 18:37 macaque_specialized_fibroblasts_kcnn3+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Specialized_Fibroblasts_KCNN3+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 169 Nov  4 18:37 marmoset_specialized_fibroblasts_kcnn3+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Specialized_Fibroblasts_KCNN3+.fragments.tsv.gz
# \n📂 Fragment files for Specialized_Fibroblasts_PCDH9+:
# total 4.0K
# lrwxrwxrwx 1 jjanssens jjanssens-group 168 Nov  4 18:37 macaque_specialized_fibroblasts_pcdh9+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Specialized_Fibroblasts_PCDH9+.fragments.tsv.gz
# \n📂 Fragment files for Specialized_Fibroblasts_RALYL+:
# total 12K
# lrwxrwxrwx 1 jjanssens jjanssens-group 171 Nov  4 18:37 chimpanzee_specialized_fibroblasts_ralyl+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Specialized_Fibroblasts_RALYL+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 168 Nov  4 18:37 gorilla_specialized_fibroblasts_ralyl+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Specialized_Fibroblasts_RALYL+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 168 Nov  4 18:37 macaque_specialized_fibroblasts_ralyl+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Specialized_Fibroblasts_RALYL+.fragments.tsv.gz
# \n📂 Fragment files for Specialized_Fibroblasts_RSPO2_3+:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 169 Nov  4 18:37 bonobo_specialized_fibroblasts_rspo2_3+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Specialized_Fibroblasts_RSPO2_3+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 173 Nov  4 18:37 chimpanzee_specialized_fibroblasts_rspo2_3+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Specialized_Fibroblasts_RSPO2_3+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 170 Nov  4 18:37 gorilla_specialized_fibroblasts_rspo2_3+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Specialized_Fibroblasts_RSPO2_3+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 168 Nov  4 18:37 human_specialized_fibroblasts_rspo2_3+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Specialized_Fibroblasts_RSPO2_3+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 170 Nov  4 18:37 macaque_specialized_fibroblasts_rspo2_3+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Specialized_Fibroblasts_RSPO2_3+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 171 Nov  4 18:37 marmoset_specialized_fibroblasts_rspo2_3+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Specialized_Fibroblasts_RSPO2_3+.fragments.tsv.gz
# \n📂 Fragment files for Specialized_Fibroblasts_RSPO3+_only:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 172 Nov  4 18:37 bonobo_specialized_fibroblasts_rspo3+_only.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Specialized_Fibroblasts_RSPO3+_only.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 176 Nov  4 18:37 chimpanzee_specialized_fibroblasts_rspo3+_only.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Specialized_Fibroblasts_RSPO3+_only.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 173 Nov  4 18:37 gorilla_specialized_fibroblasts_rspo3+_only.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Specialized_Fibroblasts_RSPO3+_only.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 171 Nov  4 18:37 human_specialized_fibroblasts_rspo3+_only.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Specialized_Fibroblasts_RSPO3+_only.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 173 Nov  4 18:37 macaque_specialized_fibroblasts_rspo3+_only.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Specialized_Fibroblasts_RSPO3+_only.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 174 Nov  4 18:37 marmoset_specialized_fibroblasts_rspo3+_only.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Specialized_Fibroblasts_RSPO3+_only.fragments.tsv.gz
# \n📂 Fragment files for Specialized_Fibroblasts_SYNM+:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 166 Nov  4 18:37 bonobo_specialized_fibroblasts_synm+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Specialized_Fibroblasts_SYNM+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 170 Nov  4 18:37 chimpanzee_specialized_fibroblasts_synm+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Specialized_Fibroblasts_SYNM+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 167 Nov  4 18:37 gorilla_specialized_fibroblasts_synm+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Specialized_Fibroblasts_SYNM+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 165 Nov  4 18:37 human_specialized_fibroblasts_synm+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Specialized_Fibroblasts_SYNM+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 167 Nov  4 18:37 macaque_specialized_fibroblasts_synm+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Specialized_Fibroblasts_SYNM+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 168 Nov  4 18:37 marmoset_specialized_fibroblasts_synm+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Specialized_Fibroblasts_SYNM+.fragments.tsv.gz
# \n📂 Fragment files for Specialized_Fibroblasts_VCAM1+:
# total 20K
# lrwxrwxrwx 1 jjanssens jjanssens-group 167 Nov  4 18:37 bonobo_specialized_fibroblasts_vcam1+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Specialized_Fibroblasts_VCAM1+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 171 Nov  4 18:37 chimpanzee_specialized_fibroblasts_vcam1+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Specialized_Fibroblasts_VCAM1+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 166 Nov  4 18:37 human_specialized_fibroblasts_vcam1+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Specialized_Fibroblasts_VCAM1+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 168 Nov  4 18:37 macaque_specialized_fibroblasts_vcam1+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Specialized_Fibroblasts_VCAM1+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 169 Nov  4 18:37 marmoset_specialized_fibroblasts_vcam1+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Specialized_Fibroblasts_VCAM1+.fragments.tsv.gz
# \n📂 Fragment files for Stem_cells:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 147 Nov  4 18:37 bonobo_stem_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Stem_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 151 Nov  4 18:37 chimpanzee_stem_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Stem_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 gorilla_stem_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Stem_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 146 Nov  4 18:37 human_stem_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Stem_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 macaque_stem_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Stem_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 149 Nov  4 18:37 marmoset_stem_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Stem_cells.fragments.tsv.gz
# \n📂 Fragment files for TA_cells:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 145 Nov  4 18:37 bonobo_ta_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/TA_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 149 Nov  4 18:37 chimpanzee_ta_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/TA_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 146 Nov  4 18:37 gorilla_ta_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/TA_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 144 Nov  4 18:37 human_ta_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/TA_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 146 Nov  4 18:37 macaque_ta_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/TA_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 147 Nov  4 18:37 marmoset_ta_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/TA_cells.fragments.tsv.gz
# \n📂 Fragment files for T_cells:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 144 Nov  4 18:37 bonobo_t_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/T_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 chimpanzee_t_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/T_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 145 Nov  4 18:37 gorilla_t_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/T_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 143 Nov  4 18:37 human_t_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/T_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 145 Nov  4 18:37 macaque_t_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/T_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 146 Nov  4 18:37 marmoset_t_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/T_cells.fragments.tsv.gz
# \n📂 Fragment files for Tuft_cells:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 147 Nov  4 18:37 bonobo_tuft_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Tuft_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 151 Nov  4 18:37 chimpanzee_tuft_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Tuft_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 gorilla_tuft_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Tuft_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 146 Nov  4 18:37 human_tuft_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Tuft_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 148 Nov  4 18:37 macaque_tuft_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Tuft_cells.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 149 Nov  4 18:37 marmoset_tuft_cells.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Tuft_cells.fragments.tsv.gz
# \n📂 Fragment files for Villus_Fibroblasts_WNT5B+:
# total 24K
# lrwxrwxrwx 1 jjanssens jjanssens-group 162 Nov  4 18:37 bonobo_villus_fibroblasts_wnt5b+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Bonobo/pseudobulk_bed_files/Villus_Fibroblasts_WNT5B+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 166 Nov  4 18:37 chimpanzee_villus_fibroblasts_wnt5b+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Chimpanzee/pseudobulk_bed_files/Villus_Fibroblasts_WNT5B+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 163 Nov  4 18:37 gorilla_villus_fibroblasts_wnt5b+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Gorilla/pseudobulk_bed_files/Villus_Fibroblasts_WNT5B+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 161 Nov  4 18:37 human_villus_fibroblasts_wnt5b+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Human/pseudobulk_bed_files/Villus_Fibroblasts_WNT5B+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 163 Nov  4 18:37 macaque_villus_fibroblasts_wnt5b+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Macaque/pseudobulk_bed_files/Villus_Fibroblasts_WNT5B+.fragments.tsv.gz
# lrwxrwxrwx 1 jjanssens jjanssens-group 164 Nov  4 18:37 marmoset_villus_fibroblasts_wnt5b+.fragments.tsv.gz -> /cluster/project/treutlein/USERS/jjans/analysis/adult_intestine/atac/consensus_peak_calling_Marmoset/pseudobulk_bed_files/Villus_Fibroblasts_WNT5B+.fragments.tsv.gz

# %% [markdown]
# ---
# ## Step 2: Liftover Fragments to hg38
#
# Use parallel implementation to liftover fragments from each species to the human genome (hg38).
#
# **Important:** This step requires the `liftover_fragments_par.sh` and `liftover_fragments_parchr.sh` scripts.

# %%
# Create output directories for lifted fragments (organized by cell type)
for cell_type in "${CELL_TYPES[@]}"; do
    cell_type_lower=$(echo "$cell_type" | tr '[:upper:]' '[:lower:]')
    mkdir -p "lifted_fragments/${cell_type_lower}"
    echo "📁 Created directory: lifted_fragments/${cell_type_lower}"
done

echo "✅ Output directories created"
# Out:
# 📁 Created directory: lifted_fragments/adipocytes
# 📁 Created directory: lifted_fragments/best4+_cells
# 📁 Created directory: lifted_fragments/colonocytes
# 📁 Created directory: lifted_fragments/crypt_fibroblasts_wnt2b+
# 📁 Created directory: lifted_fragments/ecs
# 📁 Created directory: lifted_fragments/eecs
# 📁 Created directory: lifted_fragments/enteric_glia
# 📁 Created directory: lifted_fragments/enteric_neurons
# 📁 Created directory: lifted_fragments/enterocytes
# 📁 Created directory: lifted_fragments/eosinophils
# 📁 Created directory: lifted_fragments/goblet-like_cells
# 📁 Created directory: lifted_fragments/goblet_cells
# 📁 Created directory: lifted_fragments/iccs
# 📁 Created directory: lifted_fragments/ilcs
# 📁 Created directory: lifted_fragments/lymphatic_ecs
# 📁 Created directory: lifted_fragments/marco+_lymphatic_ecs
# 📁 Created directory: lifted_fragments/muc6+_cells
# 📁 Created directory: lifted_fragments/macrophages
# 📁 Created directory: lifted_fragments/mast_cells
# 📁 Created directory: lifted_fragments/mesothelial_cells
# 📁 Created directory: lifted_fragments/monocytes
# 📁 Created directory: lifted_fragments/myofibroblasts
# 📁 Created directory: lifted_fragments/naive_b_cells
# 📁 Created directory: lifted_fragments/neutrophils
# 📁 Created directory: lifted_fragments/paneth_cells
# 📁 Created directory: lifted_fragments/pericytes
# 📁 Created directory: lifted_fragments/plasma_b_cells
# 📁 Created directory: lifted_fragments/rbp2_high_cells
# 📁 Created directory: lifted_fragments/specialized_fibroblasts_adamts16+
# 📁 Created directory: lifted_fragments/specialized_fibroblasts_kcnn3+
# 📁 Created directory: lifted_fragments/specialized_fibroblasts_pcdh9+
# 📁 Created directory: lifted_fragments/specialized_fibroblasts_ralyl+
# 📁 Created directory: lifted_fragments/specialized_fibroblasts_rspo2_3+
# 📁 Created directory: lifted_fragments/specialized_fibroblasts_rspo3+_only
# 📁 Created directory: lifted_fragments/specialized_fibroblasts_synm+
# 📁 Created directory: lifted_fragments/specialized_fibroblasts_vcam1+
# 📁 Created directory: lifted_fragments/stem_cells
# 📁 Created directory: lifted_fragments/ta_cells
# 📁 Created directory: lifted_fragments/t_cells
# 📁 Created directory: lifted_fragments/tuft_cells
# 📁 Created directory: lifted_fragments/villus_fibroblasts_wnt5b+
# ✅ Output directories created

# %% [markdown]
# ### Human Fragments (No Liftover Needed)
#
# Human fragments are already in hg38, so we just create a symlink.

# %%
# Link Human fragments directly (already in hg38)
for cell_type in "${CELL_TYPES[@]}"; do
    cell_type_lower=$(echo "$cell_type" | tr '[:upper:]' '[:lower:]')
    
    source_file="fragment_files/${cell_type_lower}/human_${cell_type_lower}.fragments.tsv.gz"
    target_link="lifted_fragments/${cell_type_lower}/human_${cell_type_lower}.hg38.fragments.tsv.gz"
    
    if [[ -f "$source_file" ]]; then
        ln -sf "../../${source_file}" "$target_link"
        echo "🔗 Linked Human ${cell_type} (no liftover needed)"
    fi
done
# Out:
# 🔗 Linked Human Adipocytes (no liftover needed)
# 🔗 Linked Human BEST4+_cells (no liftover needed)
# 🔗 Linked Human Colonocytes (no liftover needed)
# 🔗 Linked Human Crypt_Fibroblasts_WNT2B+ (no liftover needed)
# 🔗 Linked Human ECs (no liftover needed)
# 🔗 Linked Human EECs (no liftover needed)
# 🔗 Linked Human Enteric_glia (no liftover needed)
# 🔗 Linked Human Enteric_neurons (no liftover needed)
# 🔗 Linked Human Enterocytes (no liftover needed)
# 🔗 Linked Human Goblet_cells (no liftover needed)
# 🔗 Linked Human ICCs (no liftover needed)
# 🔗 Linked Human ILCs (no liftover needed)
# 🔗 Linked Human Lymphatic_ECs (no liftover needed)
# 🔗 Linked Human MUC6+_cells (no liftover needed)
# 🔗 Linked Human Macrophages (no liftover needed)
# 🔗 Linked Human Mast_cells (no liftover needed)
# 🔗 Linked Human Monocytes (no liftover needed)
# 🔗 Linked Human Myofibroblasts (no liftover needed)
# 🔗 Linked Human Naive_B_cells (no liftover needed)
# 🔗 Linked Human Paneth_cells (no liftover needed)
# 🔗 Linked Human Pericytes (no liftover needed)
# 🔗 Linked Human Plasma_B_cells (no liftover needed)
# 🔗 Linked Human Specialized_Fibroblasts_KCNN3+ (no liftover needed)
# 🔗 Linked Human Specialized_Fibroblasts_RSPO2_3+ (no liftover needed)
# 🔗 Linked Human Specialized_Fibroblasts_RSPO3+_only (no liftover needed)
# 🔗 Linked Human Specialized_Fibroblasts_SYNM+ (no liftover needed)
# 🔗 Linked Human Specialized_Fibroblasts_VCAM1+ (no liftover needed)
# 🔗 Linked Human Stem_cells (no liftover needed)
# 🔗 Linked Human TA_cells (no liftover needed)
# 🔗 Linked Human T_cells (no liftover needed)
# 🔗 Linked Human Tuft_cells (no liftover needed)
# 🔗 Linked Human Villus_Fibroblasts_WNT5B+ (no liftover needed)

# %% [markdown]
# ### Standard Species Liftover (Gorilla, Chimpanzee, Bonobo, Macaque)
#
# Single-step liftover using parallel implementation with 30 CPUs.

# %%
for cell_type in "${CELL_TYPES[@]}"; do
  ct=$(echo "$cell_type" | tr '[:upper:]' '[:lower:]')
  for species in "${STANDARD_SPECIES[@]}"; do
    sp=$(echo "$species" | tr '[:upper:]' '[:lower:]')
    out="lifted_fragments/${ct}/${sp}_${ct}.hg38.fragments_par.tsv.gz"
    if [[ ! -s "$out" ]] || ! gzip -t "$out" &>/dev/null; then
      echo "TODO: $species $cell_type"
    fi
  done
done
# Out:
# TODO: Chimpanzee Enteric_neurons
# TODO: Chimpanzee Eosinophils
# TODO: Macaque Eosinophils
# TODO: Gorilla Goblet-like_cells
# TODO: Chimpanzee Goblet-like_cells
# TODO: Bonobo Goblet-like_cells
# TODO: Macaque Goblet-like_cells
# TODO: Bonobo Goblet_cells
# TODO: Macaque Goblet_cells
# TODO: Gorilla ICCs
# TODO: Chimpanzee ICCs
# TODO: Bonobo ICCs
# TODO: Macaque ICCs
# TODO: Gorilla ILCs
# TODO: Chimpanzee ILCs
# TODO: Bonobo ILCs
# TODO: Macaque ILCs
# TODO: Gorilla Lymphatic_ECs
# TODO: Chimpanzee Lymphatic_ECs
# TODO: Bonobo Lymphatic_ECs
# TODO: Macaque Lymphatic_ECs
# TODO: Gorilla MARCO+_Lymphatic_ECs
# TODO: Chimpanzee MARCO+_Lymphatic_ECs
# TODO: Bonobo MARCO+_Lymphatic_ECs
# TODO: Macaque MARCO+_Lymphatic_ECs
# TODO: Gorilla MUC6+_cells
# TODO: Chimpanzee MUC6+_cells
# TODO: Bonobo MUC6+_cells
# TODO: Macaque MUC6+_cells
# TODO: Gorilla Macrophages
# TODO: Chimpanzee Macrophages
# TODO: Bonobo Macrophages
# TODO: Macaque Macrophages
# TODO: Gorilla Mast_cells
# TODO: Chimpanzee Mast_cells
# TODO: Bonobo Mast_cells
# TODO: Macaque Mast_cells
# TODO: Gorilla Mesothelial_cells
# TODO: Chimpanzee Mesothelial_cells
# TODO: Bonobo Mesothelial_cells
# TODO: Macaque Mesothelial_cells
# TODO: Gorilla Monocytes
# TODO: Chimpanzee Monocytes
# TODO: Bonobo Monocytes
# TODO: Macaque Monocytes
# TODO: Gorilla Myofibroblasts
# TODO: Chimpanzee Myofibroblasts
# TODO: Bonobo Myofibroblasts
# TODO: Macaque Myofibroblasts
# TODO: Gorilla Naive_B_cells
# TODO: Chimpanzee Naive_B_cells
# TODO: Bonobo Naive_B_cells
# TODO: Macaque Naive_B_cells
# TODO: Gorilla Neutrophils
# TODO: Chimpanzee Neutrophils
# TODO: Bonobo Neutrophils
# TODO: Macaque Neutrophils
# TODO: Gorilla Paneth_cells
# TODO: Chimpanzee Paneth_cells
# TODO: Bonobo Paneth_cells
# TODO: Macaque Paneth_cells
# TODO: Gorilla Pericytes
# TODO: Chimpanzee Pericytes
# TODO: Bonobo Pericytes
# TODO: Macaque Pericytes
# TODO: Gorilla Plasma_B_cells
# TODO: Chimpanzee Plasma_B_cells
# TODO: Bonobo Plasma_B_cells
# TODO: Macaque Plasma_B_cells
# TODO: Gorilla RBP2_high_cells
# TODO: Chimpanzee RBP2_high_cells
# TODO: Bonobo RBP2_high_cells
# TODO: Macaque RBP2_high_cells
# TODO: Gorilla Specialized_Fibroblasts_ADAMTS16+
# TODO: Chimpanzee Specialized_Fibroblasts_ADAMTS16+
# TODO: Bonobo Specialized_Fibroblasts_ADAMTS16+
# TODO: Macaque Specialized_Fibroblasts_ADAMTS16+
# TODO: Gorilla Specialized_Fibroblasts_KCNN3+
# TODO: Chimpanzee Specialized_Fibroblasts_KCNN3+
# TODO: Bonobo Specialized_Fibroblasts_KCNN3+
# TODO: Macaque Specialized_Fibroblasts_KCNN3+
# TODO: Gorilla Specialized_Fibroblasts_PCDH9+
# TODO: Chimpanzee Specialized_Fibroblasts_PCDH9+
# TODO: Bonobo Specialized_Fibroblasts_PCDH9+
# TODO: Macaque Specialized_Fibroblasts_PCDH9+
# TODO: Gorilla Specialized_Fibroblasts_RALYL+
# TODO: Chimpanzee Specialized_Fibroblasts_RALYL+
# TODO: Bonobo Specialized_Fibroblasts_RALYL+
# TODO: Macaque Specialized_Fibroblasts_RALYL+
# TODO: Gorilla Specialized_Fibroblasts_RSPO2_3+
# TODO: Chimpanzee Specialized_Fibroblasts_RSPO2_3+
# TODO: Bonobo Specialized_Fibroblasts_RSPO2_3+
# TODO: Macaque Specialized_Fibroblasts_RSPO2_3+
# TODO: Gorilla Specialized_Fibroblasts_RSPO3+_only
# TODO: Chimpanzee Specialized_Fibroblasts_RSPO3+_only
# TODO: Bonobo Specialized_Fibroblasts_RSPO3+_only
# TODO: Macaque Specialized_Fibroblasts_RSPO3+_only
# TODO: Gorilla Specialized_Fibroblasts_SYNM+
# TODO: Chimpanzee Specialized_Fibroblasts_SYNM+
# TODO: Bonobo Specialized_Fibroblasts_SYNM+
# TODO: Macaque Specialized_Fibroblasts_SYNM+
# TODO: Gorilla Specialized_Fibroblasts_VCAM1+
# TODO: Chimpanzee Specialized_Fibroblasts_VCAM1+
# TODO: Bonobo Specialized_Fibroblasts_VCAM1+
# TODO: Macaque Specialized_Fibroblasts_VCAM1+
# TODO: Gorilla Stem_cells
# TODO: Chimpanzee Stem_cells
# TODO: Bonobo Stem_cells
# TODO: Macaque Stem_cells
# TODO: Gorilla TA_cells
# TODO: Chimpanzee TA_cells
# TODO: Bonobo TA_cells
# TODO: Macaque TA_cells
# TODO: Gorilla T_cells
# TODO: Chimpanzee T_cells
# TODO: Bonobo T_cells
# TODO: Macaque T_cells
# TODO: Gorilla Tuft_cells
# TODO: Chimpanzee Tuft_cells
# TODO: Bonobo Tuft_cells
# TODO: Macaque Tuft_cells
# TODO: Gorilla Villus_Fibroblasts_WNT5B+
# TODO: Chimpanzee Villus_Fibroblasts_WNT5B+
# TODO: Bonobo Villus_Fibroblasts_WNT5B+
# TODO: Macaque Villus_Fibroblasts_WNT5B+

# %%
STANDARD_SPECIES=("Gorilla" "Chimpanzee" "Bonobo" "Macaque")  # add "Marmoset" if you want it
# expects: CELL_TYPES array and CHAIN_FILES associative array (declare -A CHAIN_FILES)

is_complete() {
    local f="$1"
    [[ -s "$f" ]] && gzip -t "$f" &>/dev/null
}

for cell_type in "${CELL_TYPES[@]}"; do
    cell_type_lower=$(echo "$cell_type" | tr '[:upper:]' '[:lower:]')

    for species in "${STANDARD_SPECIES[@]}"; do
        species_lower=$(echo "$species" | tr '[:upper:]' '[:lower:]')

        input_file="fragment_files/${cell_type_lower}/${species_lower}_${cell_type_lower}.fragments.tsv.gz"
        chain_file="${CHAIN_FILES[$species]:-}"  # may be empty if not set
        output_file="lifted_fragments/${cell_type_lower}/${species_lower}_${cell_type_lower}.hg38.fragments_par.tsv.gz"
        tmp_file="${output_file}.partial"
        log_file="lifted_fragments/${cell_type_lower}/${species_lower}_${cell_type_lower}.log"

        # Ensure dirs exist
        mkdir -p "$(dirname "$output_file")" "$(dirname "$log_file")"

        # Basic presence checks
        if [[ ! -f "$input_file" ]]; then
            echo "⚠️  Skipping ${species} ${cell_type} (missing input: $input_file)"
            echo ""
            continue
        fi
        if [[ -z "${chain_file}" || ! -f "${chain_file}" ]]; then
            echo "⚠️  Skipping ${species} ${cell_type} (missing chain file mapping for ${species})"
            echo ""
            continue
        fi

        # Already complete? skip
        if is_complete "$output_file"; then
            echo "⏭️  Already done: ${species} ${cell_type} — skipping"
            echo ""
            continue
        fi

        # If an output exists but is invalid, clean it
        if [[ -f "$output_file" ]]; then
            if ! is_complete "$output_file"; then
                echo "🧹 Removing corrupt/partial $output_file"
                rm -f "$output_file"
            fi
        fi
        [[ -f "$tmp_file" ]] && { echo "🧹 Removing leftover $tmp_file"; rm -f "$tmp_file"; }

        echo "🚀 Running liftover for ${species} ${cell_type}..."
        bash ./liftover_fragments_par.sh \
            --i "$input_file" \
            --c "$chain_file" \
            --o "$tmp_file" \
            --ncpu 30 \
            &> "$log_file" || { echo "❌ Liftover failed — see $log_file"; echo ""; continue; }

        if is_complete "$tmp_file"; then
            mv -f "$tmp_file" "$output_file"
            echo "✅ Done with ${species} ${cell_type}"
        else
            echo "❌ Output failed validation for ${species} ${cell_type} — see $log_file"
            rm -f "$tmp_file"
        fi
        echo ""
    done
done

echo "✅ Standard species liftover resumed/completed"
# Out:
# ⏭️  Already done: Gorilla Adipocytes — skipping
#
# ⏭️  Already done: Chimpanzee Adipocytes — skipping
#
# ⏭️  Already done: Bonobo Adipocytes — skipping
#
# ⏭️  Already done: Macaque Adipocytes — skipping
#
# ⏭️  Already done: Gorilla BEST4+_cells — skipping
#
# ⏭️  Already done: Chimpanzee BEST4+_cells — skipping
#
# ⏭️  Already done: Bonobo BEST4+_cells — skipping
#
# ⏭️  Already done: Macaque BEST4+_cells — skipping
#
# ⏭️  Already done: Gorilla Colonocytes — skipping
#
# ⏭️  Already done: Chimpanzee Colonocytes — skipping
#
# ⏭️  Already done: Bonobo Colonocytes — skipping
#
# ⏭️  Already done: Macaque Colonocytes — skipping
#
# ⏭️  Already done: Gorilla Crypt_Fibroblasts_WNT2B+ — skipping
#
# ⏭️  Already done: Chimpanzee Crypt_Fibroblasts_WNT2B+ — skipping
#
# ⏭️  Already done: Bonobo Crypt_Fibroblasts_WNT2B+ — skipping
#
# ⏭️  Already done: Macaque Crypt_Fibroblasts_WNT2B+ — skipping
#
# ⏭️  Already done: Gorilla ECs — skipping
#
# ⏭️  Already done: Chimpanzee ECs — skipping
#
# ⏭️  Already done: Bonobo ECs — skipping
#
# ⏭️  Already done: Macaque ECs — skipping
#
# ⏭️  Already done: Gorilla EECs — skipping
#
# ⏭️  Already done: Chimpanzee EECs — skipping
#
# ⏭️  Already done: Bonobo EECs — skipping
#
# ⏭️  Already done: Macaque EECs — skipping
#
# ⏭️  Already done: Gorilla Enteric_glia — skipping
#
# ⏭️  Already done: Chimpanzee Enteric_glia — skipping
#
# ⏭️  Already done: Bonobo Enteric_glia — skipping
#
# ⏭️  Already done: Macaque Enteric_glia — skipping
#
# ⏭️  Already done: Gorilla Enteric_neurons — skipping
#
# ⚠️  Skipping Chimpanzee Enteric_neurons (missing input: fragment_files/enteric_neurons/chimpanzee_enteric_neurons.fragments.tsv.gz)
#
# ⏭️  Already done: Bonobo Enteric_neurons — skipping
#
# ⏭️  Already done: Macaque Enteric_neurons — skipping
#
# ⏭️  Already done: Gorilla Enterocytes — skipping
#
# ⏭️  Already done: Chimpanzee Enterocytes — skipping
#
# ⏭️  Already done: Bonobo Enterocytes — skipping
#
# ⏭️  Already done: Macaque Enterocytes — skipping
#
# ⏭️  Already done: Gorilla Eosinophils — skipping
#
# ⚠️  Skipping Chimpanzee Eosinophils (missing input: fragment_files/eosinophils/chimpanzee_eosinophils.fragments.tsv.gz)
#
# ⏭️  Already done: Bonobo Eosinophils — skipping
#
# ⚠️  Skipping Macaque Eosinophils (missing input: fragment_files/eosinophils/macaque_eosinophils.fragments.tsv.gz)
#
# ⚠️  Skipping Gorilla Goblet-like_cells (missing input: fragment_files/goblet-like_cells/gorilla_goblet-like_cells.fragments.tsv.gz)
#
# ⚠️  Skipping Chimpanzee Goblet-like_cells (missing input: fragment_files/goblet-like_cells/chimpanzee_goblet-like_cells.fragments.tsv.gz)
#
# ⚠️  Skipping Bonobo Goblet-like_cells (missing input: fragment_files/goblet-like_cells/bonobo_goblet-like_cells.fragments.tsv.gz)
#
# ⚠️  Skipping Macaque Goblet-like_cells (missing input: fragment_files/goblet-like_cells/macaque_goblet-like_cells.fragments.tsv.gz)
#
# ⏭️  Already done: Gorilla Goblet_cells — skipping
#
# ⏭️  Already done: Chimpanzee Goblet_cells — skipping
#
# ⏭️  Already done: Bonobo Goblet_cells — skipping
#
# ⏭️  Already done: Macaque Goblet_cells — skipping
#
# ⏭️  Already done: Gorilla ICCs — skipping
#
# ⏭️  Already done: Chimpanzee ICCs — skipping
#
# ⏭️  Already done: Bonobo ICCs — skipping
#
# ⏭️  Already done: Macaque ICCs — skipping
#
# ⚠️  Skipping Gorilla ILCs (missing input: fragment_files/ilcs/gorilla_ilcs.fragments.tsv.gz)
#
# ⚠️  Skipping Chimpanzee ILCs (missing input: fragment_files/ilcs/chimpanzee_ilcs.fragments.tsv.gz)
#
# ⚠️  Skipping Bonobo ILCs (missing input: fragment_files/ilcs/bonobo_ilcs.fragments.tsv.gz)
#
# ⚠️  Skipping Macaque ILCs (missing input: fragment_files/ilcs/macaque_ilcs.fragments.tsv.gz)
#
# ⏭️  Already done: Gorilla Lymphatic_ECs — skipping
#
# ⏭️  Already done: Chimpanzee Lymphatic_ECs — skipping
#
# ⏭️  Already done: Bonobo Lymphatic_ECs — skipping
#
# ⏭️  Already done: Macaque Lymphatic_ECs — skipping
#
# ⚠️  Skipping Gorilla MARCO+_Lymphatic_ECs (missing input: fragment_files/marco+_lymphatic_ecs/gorilla_marco+_lymphatic_ecs.fragments.tsv.gz)
#
# ⚠️  Skipping Chimpanzee MARCO+_Lymphatic_ECs (missing input: fragment_files/marco+_lymphatic_ecs/chimpanzee_marco+_lymphatic_ecs.fragments.tsv.gz)
#
# ⏭️  Already done: Bonobo MARCO+_Lymphatic_ECs — skipping
#
# ⚠️  Skipping Macaque MARCO+_Lymphatic_ECs (missing input: fragment_files/marco+_lymphatic_ecs/macaque_marco+_lymphatic_ecs.fragments.tsv.gz)
#
# ⚠️  Skipping Gorilla MUC6+_cells (missing input: fragment_files/muc6+_cells/gorilla_muc6+_cells.fragments.tsv.gz)
#
# ⏭️  Already done: Chimpanzee MUC6+_cells — skipping
#
# ⏭️  Already done: Bonobo MUC6+_cells — skipping
#
# ⚠️  Skipping Macaque MUC6+_cells (missing input: fragment_files/muc6+_cells/macaque_muc6+_cells.fragments.tsv.gz)
#
# ⏭️  Already done: Gorilla Macrophages — skipping
#
# ⏭️  Already done: Chimpanzee Macrophages — skipping
#
# ⏭️  Already done: Bonobo Macrophages — skipping
#
# ⏭️  Already done: Macaque Macrophages — skipping
#
# ⏭️  Already done: Gorilla Mast_cells — skipping
#
# ⏭️  Already done: Chimpanzee Mast_cells — skipping
#
# ⏭️  Already done: Bonobo Mast_cells — skipping
#
# ⚠️  Skipping Macaque Mast_cells (missing input: fragment_files/mast_cells/macaque_mast_cells.fragments.tsv.gz)
#
# ⏭️  Already done: Gorilla Mesothelial_cells — skipping
#
# ⏭️  Already done: Chimpanzee Mesothelial_cells — skipping
#
# ⏭️  Already done: Bonobo Mesothelial_cells — skipping
#
# ⏭️  Already done: Macaque Mesothelial_cells — skipping
#
# ⚠️  Skipping Gorilla Monocytes (missing input: fragment_files/monocytes/gorilla_monocytes.fragments.tsv.gz)
#
# ⏭️  Already done: Chimpanzee Monocytes — skipping
#
# ⏭️  Already done: Bonobo Monocytes — skipping
#
# ⏭️  Already done: Macaque Monocytes — skipping
#
# ⏭️  Already done: Gorilla Myofibroblasts — skipping
#
# ⏭️  Already done: Chimpanzee Myofibroblasts — skipping
#
# ⏭️  Already done: Bonobo Myofibroblasts — skipping
#
# ⏭️  Already done: Macaque Myofibroblasts — skipping
#
# ⏭️  Already done: Gorilla Naive_B_cells — skipping
#
# ⏭️  Already done: Chimpanzee Naive_B_cells — skipping
#
# ⏭️  Already done: Bonobo Naive_B_cells — skipping
#
# ⏭️  Already done: Macaque Naive_B_cells — skipping
#
# ⏭️  Already done: Gorilla Neutrophils — skipping
#
# ⚠️  Skipping Chimpanzee Neutrophils (missing input: fragment_files/neutrophils/chimpanzee_neutrophils.fragments.tsv.gz)
#
# ⏭️  Already done: Bonobo Neutrophils — skipping
#
# ⚠️  Skipping Macaque Neutrophils (missing input: fragment_files/neutrophils/macaque_neutrophils.fragments.tsv.gz)
#
# ⏭️  Already done: Gorilla Paneth_cells — skipping
#
# ⏭️  Already done: Chimpanzee Paneth_cells — skipping
#
# ⏭️  Already done: Bonobo Paneth_cells — skipping
#
# ⏭️  Already done: Macaque Paneth_cells — skipping
#
# ⏭️  Already done: Gorilla Pericytes — skipping
#
# ⏭️  Already done: Chimpanzee Pericytes — skipping
#
# ⏭️  Already done: Bonobo Pericytes — skipping
#
# ⏭️  Already done: Macaque Pericytes — skipping
#
# ⏭️  Already done: Gorilla Plasma_B_cells — skipping
#
# ⏭️  Already done: Chimpanzee Plasma_B_cells — skipping
#
# ⏭️  Already done: Bonobo Plasma_B_cells — skipping
#
# ⏭️  Already done: Macaque Plasma_B_cells — skipping
#
# ⚠️  Skipping Gorilla RBP2_high_cells (missing input: fragment_files/rbp2_high_cells/gorilla_rbp2_high_cells.fragments.tsv.gz)
#
# ⚠️  Skipping Chimpanzee RBP2_high_cells (missing input: fragment_files/rbp2_high_cells/chimpanzee_rbp2_high_cells.fragments.tsv.gz)
#
# ⚠️  Skipping Bonobo RBP2_high_cells (missing input: fragment_files/rbp2_high_cells/bonobo_rbp2_high_cells.fragments.tsv.gz)
#
# ⚠️  Skipping Macaque RBP2_high_cells (missing input: fragment_files/rbp2_high_cells/macaque_rbp2_high_cells.fragments.tsv.gz)
#
# ⏭️  Already done: Gorilla Specialized_Fibroblasts_ADAMTS16+ — skipping
#
# ⚠️  Skipping Chimpanzee Specialized_Fibroblasts_ADAMTS16+ (missing input: fragment_files/specialized_fibroblasts_adamts16+/chimpanzee_specialized_fibroblasts_adamts16+.fragments.tsv.gz)
#
# ⚠️  Skipping Bonobo Specialized_Fibroblasts_ADAMTS16+ (missing input: fragment_files/specialized_fibroblasts_adamts16+/bonobo_specialized_fibroblasts_adamts16+.fragments.tsv.gz)
#
# ⚠️  Skipping Macaque Specialized_Fibroblasts_ADAMTS16+ (missing input: fragment_files/specialized_fibroblasts_adamts16+/macaque_specialized_fibroblasts_adamts16+.fragments.tsv.gz)
#
# ⏭️  Already done: Gorilla Specialized_Fibroblasts_KCNN3+ — skipping
#
# ⏭️  Already done: Chimpanzee Specialized_Fibroblasts_KCNN3+ — skipping
#
# ⏭️  Already done: Bonobo Specialized_Fibroblasts_KCNN3+ — skipping
#
# ⏭️  Already done: Macaque Specialized_Fibroblasts_KCNN3+ — skipping
#
# ⚠️  Skipping Gorilla Specialized_Fibroblasts_PCDH9+ (missing input: fragment_files/specialized_fibroblasts_pcdh9+/gorilla_specialized_fibroblasts_pcdh9+.fragments.tsv.gz)
#
# ⚠️  Skipping Chimpanzee Specialized_Fibroblasts_PCDH9+ (missing input: fragment_files/specialized_fibroblasts_pcdh9+/chimpanzee_specialized_fibroblasts_pcdh9+.fragments.tsv.gz)
#
# ⚠️  Skipping Bonobo Specialized_Fibroblasts_PCDH9+ (missing input: fragment_files/specialized_fibroblasts_pcdh9+/bonobo_specialized_fibroblasts_pcdh9+.fragments.tsv.gz)
#
# ⏭️  Already done: Macaque Specialized_Fibroblasts_PCDH9+ — skipping
#
# ⏭️  Already done: Gorilla Specialized_Fibroblasts_RALYL+ — skipping
#
# ⏭️  Already done: Chimpanzee Specialized_Fibroblasts_RALYL+ — skipping
#
# ⚠️  Skipping Bonobo Specialized_Fibroblasts_RALYL+ (missing input: fragment_files/specialized_fibroblasts_ralyl+/bonobo_specialized_fibroblasts_ralyl+.fragments.tsv.gz)
#
# ⏭️  Already done: Macaque Specialized_Fibroblasts_RALYL+ — skipping
#
# ⏭️  Already done: Gorilla Specialized_Fibroblasts_RSPO2_3+ — skipping
#
# ⏭️  Already done: Chimpanzee Specialized_Fibroblasts_RSPO2_3+ — skipping
#
# ⏭️  Already done: Bonobo Specialized_Fibroblasts_RSPO2_3+ — skipping
#
# ⏭️  Already done: Macaque Specialized_Fibroblasts_RSPO2_3+ — skipping
#
# ⏭️  Already done: Gorilla Specialized_Fibroblasts_RSPO3+_only — skipping
#
# ⏭️  Already done: Chimpanzee Specialized_Fibroblasts_RSPO3+_only — skipping
#
# ⏭️  Already done: Bonobo Specialized_Fibroblasts_RSPO3+_only — skipping
#
# ⏭️  Already done: Macaque Specialized_Fibroblasts_RSPO3+_only — skipping
#
# ⏭️  Already done: Gorilla Specialized_Fibroblasts_SYNM+ — skipping
#
# ⏭️  Already done: Chimpanzee Specialized_Fibroblasts_SYNM+ — skipping
#
# ⏭️  Already done: Bonobo Specialized_Fibroblasts_SYNM+ — skipping
#
# ⏭️  Already done: Macaque Specialized_Fibroblasts_SYNM+ — skipping
#
# ⚠️  Skipping Gorilla Specialized_Fibroblasts_VCAM1+ (missing input: fragment_files/specialized_fibroblasts_vcam1+/gorilla_specialized_fibroblasts_vcam1+.fragments.tsv.gz)
#
# ⏭️  Already done: Chimpanzee Specialized_Fibroblasts_VCAM1+ — skipping
#
# ⏭️  Already done: Bonobo Specialized_Fibroblasts_VCAM1+ — skipping
#
# ⏭️  Already done: Macaque Specialized_Fibroblasts_VCAM1+ — skipping
#
# ⏭️  Already done: Gorilla Stem_cells — skipping
#
# ⏭️  Already done: Chimpanzee Stem_cells — skipping
#
# ⏭️  Already done: Bonobo Stem_cells — skipping
#
# ⏭️  Already done: Macaque Stem_cells — skipping
#
# ⏭️  Already done: Gorilla TA_cells — skipping
#
# ⏭️  Already done: Chimpanzee TA_cells — skipping
#
# ⏭️  Already done: Bonobo TA_cells — skipping
#
# ⏭️  Already done: Macaque TA_cells — skipping
#
# ⏭️  Already done: Gorilla T_cells — skipping
#
# ⏭️  Already done: Chimpanzee T_cells — skipping
#
# ⏭️  Already done: Bonobo T_cells — skipping
#
# ⏭️  Already done: Macaque T_cells — skipping
#
# ⏭️  Already done: Gorilla Tuft_cells — skipping
#
# ⏭️  Already done: Chimpanzee Tuft_cells — skipping
#
# ⏭️  Already done: Bonobo Tuft_cells — skipping
#
# ⏭️  Already done: Macaque Tuft_cells — skipping
#
# ⏭️  Already done: Gorilla Villus_Fibroblasts_WNT5B+ — skipping
#
# ⏭️  Already done: Chimpanzee Villus_Fibroblasts_WNT5B+ — skipping
#
# ⏭️  Already done: Bonobo Villus_Fibroblasts_WNT5B+ — skipping
#
# ⏭️  Already done: Macaque Villus_Fibroblasts_WNT5B+ — skipping
#
# ✅ Standard species liftover resumed/completed

# %%
# Liftover for standard species (single-step)
STANDARD_SPECIES=("Gorilla" "Chimpanzee" "Bonobo" "Macaque")

for cell_type in "${CELL_TYPES[@]}"; do
    cell_type_lower=$(echo "$cell_type" | tr '[:upper:]' '[:lower:]')
    
    for species in "${STANDARD_SPECIES[@]}"; do
        species_lower=$(echo "$species" | tr '[:upper:]' '[:lower:]')
        
        input_file="fragment_files/${cell_type_lower}/${species_lower}_${cell_type_lower}.fragments.tsv.gz"
        chain_file="${CHAIN_FILES[$species]}"
        output_file="lifted_fragments/${cell_type_lower}/${species_lower}_${cell_type_lower}.hg38.fragments_par.tsv.gz"
        log_file="lifted_fragments/${cell_type_lower}/${species_lower}_${cell_type_lower}.log"
        
        if [[ -f "$input_file" && -f "$chain_file" ]]; then
            echo "🚀 Running liftover for ${species} ${cell_type}..."
            bash liftover_fragments_par.sh \
                --i "$input_file" \
                --c "$chain_file" \
                --o "$output_file" \
                --ncpu 30 \
                &> "$log_file"
            echo "✅ Done with ${species} ${cell_type}"
        else
            echo "⚠️  Skipping ${species} ${cell_type} (missing input or chain file)"
        fi
        echo ""
    done
done

echo "✅ Standard species liftover completed"
# Out:
# 🚀 Running liftover for Gorilla Adipocytes...
# ✅ Done with Gorilla Adipocytes
#
# 🚀 Running liftover for Chimpanzee Adipocytes...
# ✅ Done with Chimpanzee Adipocytes
#
# 🚀 Running liftover for Bonobo Adipocytes...
# ✅ Done with Bonobo Adipocytes
#
# 🚀 Running liftover for Macaque Adipocytes...
# ✅ Done with Macaque Adipocytes
#
# 🚀 Running liftover for Gorilla BEST4+_cells...
# ✅ Done with Gorilla BEST4+_cells
#
# 🚀 Running liftover for Chimpanzee BEST4+_cells...
# ✅ Done with Chimpanzee BEST4+_cells
#
# 🚀 Running liftover for Bonobo BEST4+_cells...
# ✅ Done with Bonobo BEST4+_cells
#
# 🚀 Running liftover for Macaque BEST4+_cells...
# ✅ Done with Macaque BEST4+_cells
#
# 🚀 Running liftover for Gorilla Colonocytes...
# ✅ Done with Gorilla Colonocytes
#
# 🚀 Running liftover for Chimpanzee Colonocytes...

# %% [markdown]
# ### Marmoset Two-Step Liftover
#
# Marmoset requires two liftover steps:
# 1. calJac1 → calJac4
# 2. calJac4 → hg38

# %%
# Marmoset liftover - Step 1: calJac1 to calJac4
for cell_type in "${CELL_TYPES[@]}"; do
    cell_type_lower=$(echo "$cell_type" | tr '[:upper:]' '[:lower:]')
    
    input_file="fragment_files/${cell_type_lower}/marmoset_${cell_type_lower}.fragments.tsv.gz"
    chain_file="${CHAIN_FILES[Marmoset_step1]}"
    output_file="lifted_fragments/${cell_type_lower}/marmoset_${cell_type_lower}.calJac4.fragments_par.tsv.gz"
    log_file="lifted_fragments/${cell_type_lower}/marmoset_${cell_type_lower}_step1.log"
    
    # --- CHECK 1: Skip if output exists and is valid ---
    if [[ -f "$output_file" ]]; then
        # Check if the gzip file is intact and not corrupt
        if gzip -t "$output_file" 2>/dev/null; then
            echo "⏭️  Skipping Marmoset ${cell_type} Step 1 (Output exists and is complete)"
            continue
        else
            echo "⚠️  Output file for ${cell_type} exists but is corrupt/incomplete. Re-running..."
        fi
    fi
    
    # --- CHECK 2: Verify inputs exist ---
    if [[ -f "$input_file" && -f "$chain_file" ]]; then
        echo "🚀 Running Marmoset ${cell_type} liftover - Step 1 (calJac1 → calJac4)..."
        bash liftover_fragments_parchr.sh \
            --i "$input_file" \
            --c "$chain_file" \
            --o "$output_file" \
            --ncpu 30 \
            &> "$log_file"
        echo "✅ Done with Marmoset ${cell_type} Step 1"
    else
        echo "⚠️  Skipping Marmoset ${cell_type} Step 1 (missing input or chain file)"
    fi
    echo ""
done
# Out:
# ⏭️  Skipping Marmoset Adipocytes Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset BEST4+_cells Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset Colonocytes Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset Crypt_Fibroblasts_WNT2B+ Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset ECs Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset EECs Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset Enteric_glia Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset Enteric_neurons Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset Enterocytes Step 1 (Output exists and is complete)
# ⚠️  Skipping Marmoset Eosinophils Step 1 (missing input or chain file)
#
# ⏭️  Skipping Marmoset Goblet-like_cells Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset Goblet_cells Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset ICCs Step 1 (Output exists and is complete)
# ⚠️  Skipping Marmoset ILCs Step 1 (missing input or chain file)
#
# ⏭️  Skipping Marmoset Lymphatic_ECs Step 1 (Output exists and is complete)
# ⚠️  Skipping Marmoset MARCO+_Lymphatic_ECs Step 1 (missing input or chain file)
#
# ⚠️  Skipping Marmoset MUC6+_cells Step 1 (missing input or chain file)
#
# ⏭️  Skipping Marmoset Macrophages Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset Mast_cells Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset Mesothelial_cells Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset Monocytes Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset Myofibroblasts Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset Naive_B_cells Step 1 (Output exists and is complete)
# ⚠️  Skipping Marmoset Neutrophils Step 1 (missing input or chain file)
#
# ⏭️  Skipping Marmoset Paneth_cells Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset Pericytes Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset Plasma_B_cells Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset RBP2_high_cells Step 1 (Output exists and is complete)
# ⚠️  Skipping Marmoset Specialized_Fibroblasts_ADAMTS16+ Step 1 (missing input or chain file)
#
# ⏭️  Skipping Marmoset Specialized_Fibroblasts_KCNN3+ Step 1 (Output exists and is complete)
# ⚠️  Skipping Marmoset Specialized_Fibroblasts_PCDH9+ Step 1 (missing input or chain file)
#
# ⚠️  Skipping Marmoset Specialized_Fibroblasts_RALYL+ Step 1 (missing input or chain file)
#
# ⏭️  Skipping Marmoset Specialized_Fibroblasts_RSPO2_3+ Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset Specialized_Fibroblasts_RSPO3+_only Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset Specialized_Fibroblasts_SYNM+ Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset Specialized_Fibroblasts_VCAM1+ Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset Stem_cells Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset TA_cells Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset T_cells Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset Tuft_cells Step 1 (Output exists and is complete)
# ⏭️  Skipping Marmoset Villus_Fibroblasts_WNT5B+ Step 1 (Output exists and is complete)

# %%
# Marmoset liftover - Step 2: calJac4 to hg38
for cell_type in "${CELL_TYPES[@]}"; do
    cell_type_lower=$(echo "$cell_type" | tr '[:upper:]' '[:lower:]')
    
    input_file="lifted_fragments/${cell_type_lower}/marmoset_${cell_type_lower}.calJac4.fragments_par.tsv.gz"
    chain_file="${CHAIN_FILES[Marmoset_step2]}"
    output_file="lifted_fragments/${cell_type_lower}/marmoset_${cell_type_lower}.hg38.fragments_par.tsv.gz"
    log_file="lifted_fragments/${cell_type_lower}/marmoset_${cell_type_lower}_step2.log"
    
    # --- CHECK 1: PRE-RUN (Skip if already finished and valid) ---
    # gzip -t tests the integrity of the compressed file
    if [[ -f "$output_file" ]] && gzip -t "$output_file" &>/dev/null; then
        echo "⏭️  Skipping Marmoset ${cell_type} Step 2 (Output already exists and is valid)"
        continue
    fi

    if [[ -f "$input_file" && -f "$chain_file" ]]; then
        echo "🚀 Running Marmoset ${cell_type} liftover - Step 2 (calJac4 → hg38)..."
        
        bash liftover_fragments_parchr.sh \
            --i "$input_file" \
            --c "$chain_file" \
            --o "$output_file" \
            --ncpu 40 \
            &> "$log_file"

        # --- CHECK 2: POST-RUN (Verify success) ---
        if [[ -f "$output_file" ]] && gzip -t "$output_file" &>/dev/null; then
            echo "✅ Done with Marmoset ${cell_type} Step 2 (Output verified)"
        else
            echo "❌ FAILED Marmoset ${cell_type} Step 2: Output file is missing or corrupt!"
            # Optional: remove the corrupt file so it doesn't trick the check next time
            # rm -f "$output_file" 
        fi
    else
        echo "⚠️  Skipping Marmoset ${cell_type} Step 2 (missing input or chain file)"
    fi
    echo ""
done

echo "✅ Marmoset liftover completed"
# Out:
# ⏭️  Skipping Marmoset Adipocytes Step 2 (Output already exists and is valid)
# ⏭️  Skipping Marmoset BEST4+_cells Step 2 (Output already exists and is valid)
# ⏭️  Skipping Marmoset Colonocytes Step 2 (Output already exists and is valid)
# ⏭️  Skipping Marmoset Crypt_Fibroblasts_WNT2B+ Step 2 (Output already exists and is valid)
# ⏭️  Skipping Marmoset ECs Step 2 (Output already exists and is valid)
# ⏭️  Skipping Marmoset EECs Step 2 (Output already exists and is valid)
# ⏭️  Skipping Marmoset Enteric_glia Step 2 (Output already exists and is valid)
# ⏭️  Skipping Marmoset Enteric_neurons Step 2 (Output already exists and is valid)
# ⏭️  Skipping Marmoset Enterocytes Step 2 (Output already exists and is valid)
# ⚠️  Skipping Marmoset Eosinophils Step 2 (missing input or chain file)
#
# ⏭️  Skipping Marmoset Goblet-like_cells Step 2 (Output already exists and is valid)
# 🚀 Running Marmoset Goblet_cells liftover - Step 2 (calJac4 → hg38)...

# %%
# Marmoset liftover - Step 1: calJac1 to calJac4
for cell_type in "${CELL_TYPES[@]}"; do
    cell_type_lower=$(echo "$cell_type" | tr '[:upper:]' '[:lower:]')
    
    input_file="fragment_files/${cell_type_lower}/marmoset_${cell_type_lower}.fragments.tsv.gz"
    chain_file="${CHAIN_FILES[Marmoset_step1]}"
    output_file="lifted_fragments/${cell_type_lower}/marmoset_${cell_type_lower}.calJac4.fragments_par.tsv.gz"
    log_file="lifted_fragments/${cell_type_lower}/marmoset_${cell_type_lower}_step1.log"
    
    if [[ -f "$input_file" && -f "$chain_file" ]]; then
        echo "🚀 Running Marmoset ${cell_type} liftover - Step 1 (calJac1 → calJac4)..."
        bash liftover_fragments_parchr.sh \
            --i "$input_file" \
            --c "$chain_file" \
            --o "$output_file" \
            --ncpu 30 \
            &> "$log_file"
        echo "✅ Done with Marmoset ${cell_type} Step 1"
    else
        echo "⚠️  Skipping Marmoset ${cell_type} Step 1 (missing input or chain file)"
    fi
    echo ""
done
# Out:
# 🚀 Running Marmoset Adipocytes liftover - Step 1 (calJac1 → calJac4)...
# ✅ Done with Marmoset Adipocytes Step 1
#
# 🚀 Running Marmoset BEST4+_cells liftover - Step 1 (calJac1 → calJac4)...
# ✅ Done with Marmoset BEST4+_cells Step 1
#
# 🚀 Running Marmoset Colonocytes liftover - Step 1 (calJac1 → calJac4)...
# ✅ Done with Marmoset Colonocytes Step 1
#
# 🚀 Running Marmoset Crypt_Fibroblasts_WNT2B+ liftover - Step 1 (calJac1 → calJac4)...

# %%
# Marmoset liftover - Step 2: calJac4 to hg38
for cell_type in "${CELL_TYPES[@]}"; do
    cell_type_lower=$(echo "$cell_type" | tr '[:upper:]' '[:lower:]')
    
    input_file="lifted_fragments/${cell_type_lower}/marmoset_${cell_type_lower}.calJac4.fragments_par.tsv.gz"
    chain_file="${CHAIN_FILES[Marmoset_step2]}"
    output_file="lifted_fragments/${cell_type_lower}/marmoset_${cell_type_lower}.hg38.fragments_par.tsv.gz"
    log_file="lifted_fragments/${cell_type_lower}/marmoset_${cell_type_lower}_step2.log"
    
    if [[ -f "$input_file" && -f "$chain_file" ]]; then
        echo "🚀 Running Marmoset ${cell_type} liftover - Step 2 (calJac4 → hg38)..."
        bash liftover_fragments_parchr.sh \
            --i "$input_file" \
            --c "$chain_file" \
            --o "$output_file" \
            --ncpu 30 \
            &> "$log_file"
        echo "✅ Done with Marmoset ${cell_type} Step 2"
    else
        echo "⚠️  Skipping Marmoset ${cell_type} Step 2 (missing input or chain file)"
    fi
    echo ""
done

echo "✅ Marmoset liftover completed"

# %%
# Verify lifted fragment files
for cell_type in "${CELL_TYPES[@]}"; do
    cell_type_lower=$(echo "$cell_type" | tr '[:upper:]' '[:lower:]')
    echo "\n📂 Lifted fragments for ${cell_type}:"
    ls -lh "lifted_fragments/${cell_type_lower}/" | grep -E '\.hg38\.fragments.*\.tsv\.gz$'
done

# %% [markdown]
# ---
# ## Step 3: Convert Fragments to BigWig Coverage Files
#
# Convert lifted fragment files to coverage bigWig format for visualization.
#
# **Note:** Requires `scatac_fragment_tools` to be installed.

# %%
# Activate the scatac_fragment_tools environment
mamba activate scatac_fragment_tools

# %%
# Create output directories for bigWig files (organized by cell type)
for cell_type in "${CELL_TYPES[@]}"; do
    cell_type_lower=$(echo "$cell_type" | tr '[:upper:]' '[:lower:]')
    mkdir -p "bigwigs/${cell_type_lower}"
    echo "📁 Created directory: bigwigs/${cell_type_lower}"
done

echo "✅ BigWig output directories created"

# %%
# Convert fragments to bigWig for all species and cell types
# Pre-check global requirement
[[ ! -f "$CHROM_SIZES" ]] && echo "⚠️ Missing CHROM_SIZES file ($CHROM_SIZES)" && exit 1

for cell in "${CELL_TYPES[@]}"; do
    c_low="${cell,,}" 
    
    for sp in "${SPECIES[@]}"; do
        s_low="${sp,,}"
        
        # Define paths (Handle Human filename exception dynamically)
        suffix=$([[ "$sp" == "Human" ]] && echo "fragments" || echo "fragments_par")
        input="lifted_fragments/${c_low}/${s_low}_${c_low}.hg38.${suffix}.tsv.gz"
        output="bigwigs/${c_low}/${s_low}_${c_low}.hg38.cov.bw"

        # Check input existence
        [[ ! -f "$input" ]] && echo "⚠️ Missing fragments for $sp $cell" && continue

        # Check if output already exists AND is valid
        # Logic: If file exists (-s) AND (bigWigInfo is missing OR bigWigInfo says file is good)
        if [[ -s "$output" ]] && { ! command -v bigWigInfo &>/dev/null || bigWigInfo "$output" &>/dev/null; }; then
            echo "⏩ Valid bigWig exists for $sp $cell — skipping"
            continue
        fi

        # Run Conversion
        mkdir -p "$(dirname "$output")"
        echo "🎯 Converting $sp $cell..."
        
        scatac_fragment_tools bigwig -i "$input" -c "$CHROM_SIZES" -o "$output" -n

        # Final Verification
        if [[ -s "$output" ]] && { ! command -v bigWigInfo &>/dev/null || bigWigInfo "$output" &>/dev/null; }; then
            echo "✅ Done: $output"
        else
            echo "❌ Failed/Corrupt: $output"
        fi
    done
done

echo "✅ All bigWig conversions completed"

# %%
# Convert fragments to bigWig for all species and cell types
for cell_type in "${CELL_TYPES[@]}"; do
    cell_type_lower=$(echo "$cell_type" | tr '[:upper:]' '[:lower:]')
    
    for species in "${SPECIES[@]}"; do
        species_lower=$(echo "$species" | tr '[:upper:]' '[:lower:]')
        
        # Determine input file name based on species
        if [[ "$species" == "Human" ]]; then
            # Human uses direct link (no _par suffix)
            input_frag="lifted_fragments/${cell_type_lower}/${species_lower}_${cell_type_lower}.hg38.fragments.tsv.gz"
        else
            # Other species use parallel liftover output (_par suffix)
            input_frag="lifted_fragments/${cell_type_lower}/${species_lower}_${cell_type_lower}.hg38.fragments_par.tsv.gz"
        fi
        
        output_bw="bigwigs/${cell_type_lower}/${species_lower}_${cell_type_lower}.hg38.cov.bw"
        
        if [[ -f "$input_frag" && -f "$CHROM_SIZES" ]]; then
            echo "🎯 Converting ${species} ${cell_type} to bigWig..."
            scatac_fragment_tools bigwig \
                -i "$input_frag" \
                -c "$CHROM_SIZES" \
                -o "$output_bw" \
                -n
            echo "✅ Done: $output_bw"
        else
            echo "⚠️  Missing input for ${species} ${cell_type} — skipping"
        fi
        echo ""
    done
done

echo "✅ All bigWig conversions completed"

# %%
# Convert fragments to bigWig for all species and cell types
for cell_type in "${CELL_TYPES[@]}"; do
    cell_type_lower=$(echo "$cell_type" | tr '[:upper:]' '[:lower:]')
    
    for species in "${SPECIES[@]}"; do
        species_lower=$(echo "$species" | tr '[:upper:]' '[:lower:]')
        
        # Determine input file name based on species
        if [[ "$species" == "Human" ]]; then
            # Human uses direct link (no _par suffix)
            input_frag="lifted_fragments/${cell_type_lower}/${species_lower}_${cell_type_lower}.hg38.fragments.tsv.gz"
        else
            # Other species use parallel liftover output (_par suffix)
            input_frag="lifted_fragments/${cell_type_lower}/${species_lower}_${cell_type_lower}.hg38.fragments_par.tsv.gz"
        fi
        
        output_bw="bigwigs/${cell_type_lower}/${species_lower}_${cell_type_lower}.hg38.cov.bw"

        # Check inputs
        if [[ ! -f "$input_frag" ]]; then
            echo "⚠️  Missing fragments for ${species} ${cell_type} — skipping"
            echo ""
            continue
        fi
        if [[ ! -f "$CHROM_SIZES" ]]; then
            echo "⚠️  Missing CHROM_SIZES file ($CHROM_SIZES) — skipping all"
            exit 1
        fi

        # If bigWig already exists, check if it's valid
        if [[ -s "$output_bw" ]]; then
            if command -v bigWigInfo &>/dev/null; then
                if bigWigInfo "$output_bw" >/dev/null 2>&1; then
                    echo "⏩ Existing valid bigWig for ${species} ${cell_type} — skipping"
                    echo ""
                    continue
                else
                    echo "♻️ Existing bigWig for ${species} ${cell_type} seems corrupt — regenerating"
                fi
            else
                echo "ℹ️ bigWigInfo not found. Existing bigWig for ${species} ${cell_type} detected — assuming OK and skipping."
                echo ""
                continue
            fi
        fi

        # Ensure output directory exists
        mkdir -p "$(dirname "$output_bw")"

        echo "🎯 Converting ${species} ${cell_type} to bigWig..."
        scatac_fragment_tools bigwig \
            -i "$input_frag" \
            -c "$CHROM_SIZES" \
            -o "$output_bw" \
            -n

        if [[ -s "$output_bw" ]]; then
            # Optional: re-check validity after generation if bigWigInfo is available
            if command -v bigWigInfo &>/dev/null; then
                if bigWigInfo "$output_bw" >/dev/null 2>&1; then
                    echo "✅ Done & validated: $output_bw"
                else
                    echo "❌ Generated bigWig appears invalid for ${species} ${cell_type} — check logs"
                fi
            else
                echo "✅ Done: $output_bw"
            fi
        else
            echo "❌ Failed to create bigWig for ${species} ${cell_type} — empty or missing output"
        fi
        echo ""
    done
done

echo "✅ All bigWig conversions completed"
# Out:
# ⏩ Existing valid bigWig for Human Adipocytes — skipping
#
# ⏩ Existing valid bigWig for Gorilla Adipocytes — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Adipocytes — skipping
#
# ⏩ Existing valid bigWig for Bonobo Adipocytes — skipping
#
# ⏩ Existing valid bigWig for Macaque Adipocytes — skipping
#
# ⏩ Existing valid bigWig for Marmoset Adipocytes — skipping
#
# ⏩ Existing valid bigWig for Human BEST4+_cells — skipping
#
# ⏩ Existing valid bigWig for Gorilla BEST4+_cells — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee BEST4+_cells — skipping
#
# ⏩ Existing valid bigWig for Bonobo BEST4+_cells — skipping
#
# ⏩ Existing valid bigWig for Macaque BEST4+_cells — skipping
#
# ⏩ Existing valid bigWig for Marmoset BEST4+_cells — skipping
#
# ⏩ Existing valid bigWig for Human Colonocytes — skipping
#
# ⏩ Existing valid bigWig for Gorilla Colonocytes — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Colonocytes — skipping
#
# ⏩ Existing valid bigWig for Bonobo Colonocytes — skipping
#
# ⏩ Existing valid bigWig for Macaque Colonocytes — skipping
#
# ⏩ Existing valid bigWig for Marmoset Colonocytes — skipping
#
# ⏩ Existing valid bigWig for Human Crypt_Fibroblasts_WNT2B+ — skipping
#
# ⏩ Existing valid bigWig for Gorilla Crypt_Fibroblasts_WNT2B+ — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Crypt_Fibroblasts_WNT2B+ — skipping
#
# ⏩ Existing valid bigWig for Bonobo Crypt_Fibroblasts_WNT2B+ — skipping
#
# ⏩ Existing valid bigWig for Macaque Crypt_Fibroblasts_WNT2B+ — skipping
#
# ⏩ Existing valid bigWig for Marmoset Crypt_Fibroblasts_WNT2B+ — skipping
#
# ⏩ Existing valid bigWig for Human ECs — skipping
#
# ⏩ Existing valid bigWig for Gorilla ECs — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee ECs — skipping
#
# ⏩ Existing valid bigWig for Bonobo ECs — skipping
#
# ⏩ Existing valid bigWig for Macaque ECs — skipping
#
# 🎯 Converting Marmoset ECs to bigWig...
# ✅ Done & validated: bigwigs/ecs/marmoset_ecs.hg38.cov.bw
#
# ⏩ Existing valid bigWig for Human EECs — skipping
#
# ⏩ Existing valid bigWig for Gorilla EECs — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee EECs — skipping
#
# ⏩ Existing valid bigWig for Bonobo EECs — skipping
#
# ⏩ Existing valid bigWig for Macaque EECs — skipping
#
# 🎯 Converting Marmoset EECs to bigWig...
# ✅ Done & validated: bigwigs/eecs/marmoset_eecs.hg38.cov.bw
#
# ⏩ Existing valid bigWig for Human Enteric_glia — skipping
#
# ⏩ Existing valid bigWig for Gorilla Enteric_glia — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Enteric_glia — skipping
#
# ⏩ Existing valid bigWig for Bonobo Enteric_glia — skipping
#
# ⏩ Existing valid bigWig for Macaque Enteric_glia — skipping
#
# 🎯 Converting Marmoset Enteric_glia to bigWig...
# ✅ Done & validated: bigwigs/enteric_glia/marmoset_enteric_glia.hg38.cov.bw
#
# ⏩ Existing valid bigWig for Human Enteric_neurons — skipping
#
# ⏩ Existing valid bigWig for Gorilla Enteric_neurons — skipping
#
# ⚠️  Missing fragments for Chimpanzee Enteric_neurons — skipping
#
# ⏩ Existing valid bigWig for Bonobo Enteric_neurons — skipping
#
# ⏩ Existing valid bigWig for Macaque Enteric_neurons — skipping
#
# 🎯 Converting Marmoset Enteric_neurons to bigWig...
# ✅ Done & validated: bigwigs/enteric_neurons/marmoset_enteric_neurons.hg38.cov.bw
#
# ⏩ Existing valid bigWig for Human Enterocytes — skipping
#
# ⏩ Existing valid bigWig for Gorilla Enterocytes — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Enterocytes — skipping
#
# ⏩ Existing valid bigWig for Bonobo Enterocytes — skipping
#
# ⏩ Existing valid bigWig for Macaque Enterocytes — skipping
#
# ⚠️  Missing fragments for Marmoset Enterocytes — skipping
#
# ⚠️  Missing fragments for Human Eosinophils — skipping
#
# ⏩ Existing valid bigWig for Gorilla Eosinophils — skipping
#
# ⚠️  Missing fragments for Chimpanzee Eosinophils — skipping
#
# ⏩ Existing valid bigWig for Bonobo Eosinophils — skipping
#
# ⚠️  Missing fragments for Macaque Eosinophils — skipping
#
# ⚠️  Missing fragments for Marmoset Eosinophils — skipping
#
# ⚠️  Missing fragments for Human Goblet-like_cells — skipping
#
# ⚠️  Missing fragments for Gorilla Goblet-like_cells — skipping
#
# ⚠️  Missing fragments for Chimpanzee Goblet-like_cells — skipping
#
# ⚠️  Missing fragments for Bonobo Goblet-like_cells — skipping
#
# ⚠️  Missing fragments for Macaque Goblet-like_cells — skipping
#
# ⚠️  Missing fragments for Marmoset Goblet-like_cells — skipping
#
# ⏩ Existing valid bigWig for Human Goblet_cells — skipping
#
# ⏩ Existing valid bigWig for Gorilla Goblet_cells — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Goblet_cells — skipping
#
# ⏩ Existing valid bigWig for Bonobo Goblet_cells — skipping
#
# ⏩ Existing valid bigWig for Macaque Goblet_cells — skipping
#
# ⚠️  Missing fragments for Marmoset Goblet_cells — skipping
#
# ⏩ Existing valid bigWig for Human ICCs — skipping
#
# ⏩ Existing valid bigWig for Gorilla ICCs — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee ICCs — skipping
#
# ⏩ Existing valid bigWig for Bonobo ICCs — skipping
#
# ⏩ Existing valid bigWig for Macaque ICCs — skipping
#
# ⚠️  Missing fragments for Marmoset ICCs — skipping
#
# ⏩ Existing valid bigWig for Human ILCs — skipping
#
# ⚠️  Missing fragments for Gorilla ILCs — skipping
#
# ⚠️  Missing fragments for Chimpanzee ILCs — skipping
#
# ⚠️  Missing fragments for Bonobo ILCs — skipping
#
# ⚠️  Missing fragments for Macaque ILCs — skipping
#
# ⚠️  Missing fragments for Marmoset ILCs — skipping
#
# ⏩ Existing valid bigWig for Human Lymphatic_ECs — skipping
#
# ⏩ Existing valid bigWig for Gorilla Lymphatic_ECs — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Lymphatic_ECs — skipping
#
# ⏩ Existing valid bigWig for Bonobo Lymphatic_ECs — skipping
#
# ⏩ Existing valid bigWig for Macaque Lymphatic_ECs — skipping
#
# ⚠️  Missing fragments for Marmoset Lymphatic_ECs — skipping
#
# ⚠️  Missing fragments for Human MARCO+_Lymphatic_ECs — skipping
#
# ⚠️  Missing fragments for Gorilla MARCO+_Lymphatic_ECs — skipping
#
# ⚠️  Missing fragments for Chimpanzee MARCO+_Lymphatic_ECs — skipping
#
# ⏩ Existing valid bigWig for Bonobo MARCO+_Lymphatic_ECs — skipping
#
# ⚠️  Missing fragments for Macaque MARCO+_Lymphatic_ECs — skipping
#
# ⚠️  Missing fragments for Marmoset MARCO+_Lymphatic_ECs — skipping
#
# ⏩ Existing valid bigWig for Human MUC6+_cells — skipping
#
# ⚠️  Missing fragments for Gorilla MUC6+_cells — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee MUC6+_cells — skipping
#
# ⏩ Existing valid bigWig for Bonobo MUC6+_cells — skipping
#
# ⚠️  Missing fragments for Macaque MUC6+_cells — skipping
#
# ⚠️  Missing fragments for Marmoset MUC6+_cells — skipping
#
# ⏩ Existing valid bigWig for Human Macrophages — skipping
#
# ⏩ Existing valid bigWig for Gorilla Macrophages — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Macrophages — skipping
#
# ⏩ Existing valid bigWig for Bonobo Macrophages — skipping
#
# ⏩ Existing valid bigWig for Macaque Macrophages — skipping
#
# ⚠️  Missing fragments for Marmoset Macrophages — skipping
#
# ⏩ Existing valid bigWig for Human Mast_cells — skipping
#
# ⏩ Existing valid bigWig for Gorilla Mast_cells — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Mast_cells — skipping
#
# ⏩ Existing valid bigWig for Bonobo Mast_cells — skipping
#
# ⚠️  Missing fragments for Macaque Mast_cells — skipping
#
# ⚠️  Missing fragments for Marmoset Mast_cells — skipping
#
# ⚠️  Missing fragments for Human Mesothelial_cells — skipping
#
# ⏩ Existing valid bigWig for Gorilla Mesothelial_cells — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Mesothelial_cells — skipping
#
# ⏩ Existing valid bigWig for Bonobo Mesothelial_cells — skipping
#
# ⏩ Existing valid bigWig for Macaque Mesothelial_cells — skipping
#
# ⚠️  Missing fragments for Marmoset Mesothelial_cells — skipping
#
# ⏩ Existing valid bigWig for Human Monocytes — skipping
#
# ⚠️  Missing fragments for Gorilla Monocytes — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Monocytes — skipping
#
# ⏩ Existing valid bigWig for Bonobo Monocytes — skipping
#
# ⏩ Existing valid bigWig for Macaque Monocytes — skipping
#
# ⚠️  Missing fragments for Marmoset Monocytes — skipping
#
# ⏩ Existing valid bigWig for Human Myofibroblasts — skipping
#
# ⏩ Existing valid bigWig for Gorilla Myofibroblasts — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Myofibroblasts — skipping
#
# ⏩ Existing valid bigWig for Bonobo Myofibroblasts — skipping
#
# ⏩ Existing valid bigWig for Macaque Myofibroblasts — skipping
#
# ⚠️  Missing fragments for Marmoset Myofibroblasts — skipping
#
# ⏩ Existing valid bigWig for Human Naive_B_cells — skipping
#
# ⏩ Existing valid bigWig for Gorilla Naive_B_cells — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Naive_B_cells — skipping
#
# ⏩ Existing valid bigWig for Bonobo Naive_B_cells — skipping
#
# ⏩ Existing valid bigWig for Macaque Naive_B_cells — skipping
#
# ⚠️  Missing fragments for Marmoset Naive_B_cells — skipping
#
# ⚠️  Missing fragments for Human Neutrophils — skipping
#
# ⏩ Existing valid bigWig for Gorilla Neutrophils — skipping
#
# ⚠️  Missing fragments for Chimpanzee Neutrophils — skipping
#
# ⏩ Existing valid bigWig for Bonobo Neutrophils — skipping
#
# ⚠️  Missing fragments for Macaque Neutrophils — skipping
#
# ⚠️  Missing fragments for Marmoset Neutrophils — skipping
#
# ⏩ Existing valid bigWig for Human Paneth_cells — skipping
#
# ⏩ Existing valid bigWig for Gorilla Paneth_cells — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Paneth_cells — skipping
#
# ⏩ Existing valid bigWig for Bonobo Paneth_cells — skipping
#
# ⏩ Existing valid bigWig for Macaque Paneth_cells — skipping
#
# ⚠️  Missing fragments for Marmoset Paneth_cells — skipping
#
# ⏩ Existing valid bigWig for Human Pericytes — skipping
#
# ⏩ Existing valid bigWig for Gorilla Pericytes — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Pericytes — skipping
#
# ⏩ Existing valid bigWig for Bonobo Pericytes — skipping
#
# ⏩ Existing valid bigWig for Macaque Pericytes — skipping
#
# ⚠️  Missing fragments for Marmoset Pericytes — skipping
#
# ⏩ Existing valid bigWig for Human Plasma_B_cells — skipping
#
# ⏩ Existing valid bigWig for Gorilla Plasma_B_cells — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Plasma_B_cells — skipping
#
# ⏩ Existing valid bigWig for Bonobo Plasma_B_cells — skipping
#
# ⏩ Existing valid bigWig for Macaque Plasma_B_cells — skipping
#
# ⚠️  Missing fragments for Marmoset Plasma_B_cells — skipping
#
# ⚠️  Missing fragments for Human RBP2_high_cells — skipping
#
# ⚠️  Missing fragments for Gorilla RBP2_high_cells — skipping
#
# ⚠️  Missing fragments for Chimpanzee RBP2_high_cells — skipping
#
# ⚠️  Missing fragments for Bonobo RBP2_high_cells — skipping
#
# ⚠️  Missing fragments for Macaque RBP2_high_cells — skipping
#
# ⚠️  Missing fragments for Marmoset RBP2_high_cells — skipping
#
# ⚠️  Missing fragments for Human Specialized_Fibroblasts_ADAMTS16+ — skipping
#
# ⏩ Existing valid bigWig for Gorilla Specialized_Fibroblasts_ADAMTS16+ — skipping
#
# ⚠️  Missing fragments for Chimpanzee Specialized_Fibroblasts_ADAMTS16+ — skipping
#
# ⚠️  Missing fragments for Bonobo Specialized_Fibroblasts_ADAMTS16+ — skipping
#
# ⚠️  Missing fragments for Macaque Specialized_Fibroblasts_ADAMTS16+ — skipping
#
# ⚠️  Missing fragments for Marmoset Specialized_Fibroblasts_ADAMTS16+ — skipping
#
# ⏩ Existing valid bigWig for Human Specialized_Fibroblasts_KCNN3+ — skipping
#
# ⏩ Existing valid bigWig for Gorilla Specialized_Fibroblasts_KCNN3+ — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Specialized_Fibroblasts_KCNN3+ — skipping
#
# ⏩ Existing valid bigWig for Bonobo Specialized_Fibroblasts_KCNN3+ — skipping
#
# ⏩ Existing valid bigWig for Macaque Specialized_Fibroblasts_KCNN3+ — skipping
#
# ⚠️  Missing fragments for Marmoset Specialized_Fibroblasts_KCNN3+ — skipping
#
# ⚠️  Missing fragments for Human Specialized_Fibroblasts_PCDH9+ — skipping
#
# ⚠️  Missing fragments for Gorilla Specialized_Fibroblasts_PCDH9+ — skipping
#
# ⚠️  Missing fragments for Chimpanzee Specialized_Fibroblasts_PCDH9+ — skipping
#
# ⚠️  Missing fragments for Bonobo Specialized_Fibroblasts_PCDH9+ — skipping
#
# ⏩ Existing valid bigWig for Macaque Specialized_Fibroblasts_PCDH9+ — skipping
#
# ⚠️  Missing fragments for Marmoset Specialized_Fibroblasts_PCDH9+ — skipping
#
# ⚠️  Missing fragments for Human Specialized_Fibroblasts_RALYL+ — skipping
#
# ⏩ Existing valid bigWig for Gorilla Specialized_Fibroblasts_RALYL+ — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Specialized_Fibroblasts_RALYL+ — skipping
#
# ⚠️  Missing fragments for Bonobo Specialized_Fibroblasts_RALYL+ — skipping
#
# ⏩ Existing valid bigWig for Macaque Specialized_Fibroblasts_RALYL+ — skipping
#
# ⚠️  Missing fragments for Marmoset Specialized_Fibroblasts_RALYL+ — skipping
#
# ⏩ Existing valid bigWig for Human Specialized_Fibroblasts_RSPO2_3+ — skipping
#
# ⏩ Existing valid bigWig for Gorilla Specialized_Fibroblasts_RSPO2_3+ — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Specialized_Fibroblasts_RSPO2_3+ — skipping
#
# ⏩ Existing valid bigWig for Bonobo Specialized_Fibroblasts_RSPO2_3+ — skipping
#
# ⏩ Existing valid bigWig for Macaque Specialized_Fibroblasts_RSPO2_3+ — skipping
#
# ⚠️  Missing fragments for Marmoset Specialized_Fibroblasts_RSPO2_3+ — skipping
#
# ⏩ Existing valid bigWig for Human Specialized_Fibroblasts_RSPO3+_only — skipping
#
# ⏩ Existing valid bigWig for Gorilla Specialized_Fibroblasts_RSPO3+_only — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Specialized_Fibroblasts_RSPO3+_only — skipping
#
# ⏩ Existing valid bigWig for Bonobo Specialized_Fibroblasts_RSPO3+_only — skipping
#
# ⏩ Existing valid bigWig for Macaque Specialized_Fibroblasts_RSPO3+_only — skipping
#
# ⚠️  Missing fragments for Marmoset Specialized_Fibroblasts_RSPO3+_only — skipping
#
# ⏩ Existing valid bigWig for Human Specialized_Fibroblasts_SYNM+ — skipping
#
# ⏩ Existing valid bigWig for Gorilla Specialized_Fibroblasts_SYNM+ — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Specialized_Fibroblasts_SYNM+ — skipping
#
# ⏩ Existing valid bigWig for Bonobo Specialized_Fibroblasts_SYNM+ — skipping
#
# ⏩ Existing valid bigWig for Macaque Specialized_Fibroblasts_SYNM+ — skipping
#
# ⚠️  Missing fragments for Marmoset Specialized_Fibroblasts_SYNM+ — skipping
#
# ⏩ Existing valid bigWig for Human Specialized_Fibroblasts_VCAM1+ — skipping
#
# ⚠️  Missing fragments for Gorilla Specialized_Fibroblasts_VCAM1+ — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Specialized_Fibroblasts_VCAM1+ — skipping
#
# ⏩ Existing valid bigWig for Bonobo Specialized_Fibroblasts_VCAM1+ — skipping
#
# ⏩ Existing valid bigWig for Macaque Specialized_Fibroblasts_VCAM1+ — skipping
#
# ⚠️  Missing fragments for Marmoset Specialized_Fibroblasts_VCAM1+ — skipping
#
# ⏩ Existing valid bigWig for Human Stem_cells — skipping
#
# ⏩ Existing valid bigWig for Gorilla Stem_cells — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Stem_cells — skipping
#
# ⏩ Existing valid bigWig for Bonobo Stem_cells — skipping
#
# ⏩ Existing valid bigWig for Macaque Stem_cells — skipping
#
# ⚠️  Missing fragments for Marmoset Stem_cells — skipping
#
# ⏩ Existing valid bigWig for Human TA_cells — skipping
#
# ⏩ Existing valid bigWig for Gorilla TA_cells — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee TA_cells — skipping
#
# ⏩ Existing valid bigWig for Bonobo TA_cells — skipping
#
# ⏩ Existing valid bigWig for Macaque TA_cells — skipping
#
# ⚠️  Missing fragments for Marmoset TA_cells — skipping
#
# ⏩ Existing valid bigWig for Human T_cells — skipping
#
# ⏩ Existing valid bigWig for Gorilla T_cells — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee T_cells — skipping
#
# ⏩ Existing valid bigWig for Bonobo T_cells — skipping
#
# ⏩ Existing valid bigWig for Macaque T_cells — skipping
#
# ⚠️  Missing fragments for Marmoset T_cells — skipping
#
# ⏩ Existing valid bigWig for Human Tuft_cells — skipping
#
# ⏩ Existing valid bigWig for Gorilla Tuft_cells — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Tuft_cells — skipping
#
# ⏩ Existing valid bigWig for Bonobo Tuft_cells — skipping
#
# ⏩ Existing valid bigWig for Macaque Tuft_cells — skipping
#
# ⚠️  Missing fragments for Marmoset Tuft_cells — skipping
#
# ⏩ Existing valid bigWig for Human Villus_Fibroblasts_WNT5B+ — skipping
#
# ⏩ Existing valid bigWig for Gorilla Villus_Fibroblasts_WNT5B+ — skipping
#
# ⏩ Existing valid bigWig for Chimpanzee Villus_Fibroblasts_WNT5B+ — skipping
#
# ⏩ Existing valid bigWig for Bonobo Villus_Fibroblasts_WNT5B+ — skipping
#
# ⏩ Existing valid bigWig for Macaque Villus_Fibroblasts_WNT5B+ — skipping
#
# ⚠️  Missing fragments for Marmoset Villus_Fibroblasts_WNT5B+ — skipping
#
# ✅ All bigWig conversions completed

# %%
# Verify bigWig files
for cell_type in "${CELL_TYPES[@]}"; do
    cell_type_lower=$(echo "$cell_type" | tr '[:upper:]' '[:lower:]')
    echo "\n📂 BigWig files for ${cell_type}:"
    ls -lh "bigwigs/${cell_type_lower}/"
done
# Out:
# \n📂 BigWig files for Adipocytes:
# total 108M
# -rw-r----- 1 jjanssens jjanssens-group  46M Nov 12 06:47 bonobo_adipocytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  12M Nov 12 06:47 chimpanzee_adipocytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  10M Nov 12 06:47 gorilla_adipocytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  15M Nov 12 06:47 human_adipocytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 8.2M Nov 12 06:48 macaque_adipocytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  18M Nov 12 06:48 marmoset_adipocytes.hg38.cov.bw
# \n📂 BigWig files for BEST4+_cells:
# total 272M
# -rw-r----- 1 jjanssens jjanssens-group  16M Nov 12 06:49 bonobo_best4+_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  12M Nov 12 06:49 chimpanzee_best4+_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  15M Nov 12 06:49 gorilla_best4+_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 173M Nov 12 06:48 human_best4+_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  36M Nov 12 06:49 macaque_best4+_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  22M Nov 12 06:49 marmoset_best4+_cells.hg38.cov.bw
# \n📂 BigWig files for Colonocytes:
# total 986M
# -rw-r----- 1 jjanssens jjanssens-group 113M Nov 12 06:52 bonobo_colonocytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  64M Nov 12 06:52 chimpanzee_colonocytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  90M Nov 12 06:52 gorilla_colonocytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 408M Nov 12 06:51 human_colonocytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  91M Nov 12 06:53 macaque_colonocytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 220M Nov 12 06:54 marmoset_colonocytes.hg38.cov.bw
# \n📂 BigWig files for Crypt_Fibroblasts_WNT2B+:
# total 1.2G
# -rw-r----- 1 jjanssens jjanssens-group 127M Nov 12 06:58 bonobo_crypt_fibroblasts_wnt2b+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 299M Nov 12 06:57 chimpanzee_crypt_fibroblasts_wnt2b+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 195M Nov 12 06:56 gorilla_crypt_fibroblasts_wnt2b+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 201M Nov 12 06:55 human_crypt_fibroblasts_wnt2b+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  74M Nov 12 06:58 macaque_crypt_fibroblasts_wnt2b+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 270M Nov 12 06:59 marmoset_crypt_fibroblasts_wnt2b+.hg38.cov.bw
# \n📂 BigWig files for ECs:
# total 730M
# -rw-r----- 1 jjanssens jjanssens-group 122M Nov 12 07:01 bonobo_ecs.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 132M Nov 12 07:01 chimpanzee_ecs.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 122M Nov 12 07:00 gorilla_ecs.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 151M Nov 12 07:00 human_ecs.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  23M Nov 12 07:02 macaque_ecs.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 179M Nov 26 16:10 marmoset_ecs.hg38.cov.bw
# \n📂 BigWig files for EECs:
# total 385M
# -rw-r----- 1 jjanssens jjanssens-group  53M Nov 12 07:03 bonobo_eecs.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  40M Nov 12 07:03 chimpanzee_eecs.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  54M Nov 12 07:02 gorilla_eecs.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 109M Nov 12 07:02 human_eecs.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  28M Nov 12 07:03 macaque_eecs.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 103M Nov 26 16:11 marmoset_eecs.hg38.cov.bw
# \n📂 BigWig files for Enteric_glia:
# total 457M
# -rw-r----- 1 jjanssens jjanssens-group  37M Nov 12 07:05 bonobo_enteric_glia.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  66M Nov 12 07:04 chimpanzee_enteric_glia.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 129M Nov 12 07:04 gorilla_enteric_glia.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 134M Nov 12 07:03 human_enteric_glia.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  18M Nov 12 07:05 macaque_enteric_glia.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  73M Nov 26 16:11 marmoset_enteric_glia.hg38.cov.bw
# \n📂 BigWig files for Enteric_neurons:
# total 105M
# -rw-r----- 1 jjanssens jjanssens-group 4.8M Nov 12 07:05 bonobo_enteric_neurons.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 4.9M Nov 12 07:05 gorilla_enteric_neurons.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  20M Nov 12 07:05 human_enteric_neurons.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 2.2M Nov 12 07:05 macaque_enteric_neurons.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  74M Nov 26 16:11 marmoset_enteric_neurons.hg38.cov.bw
# \n📂 BigWig files for Enterocytes:
# total 1.3G
# -rw-r----- 1 jjanssens jjanssens-group 419M Nov 12 07:11 bonobo_enterocytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 387M Nov 12 07:09 chimpanzee_enterocytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  78M Nov 12 07:07 gorilla_enterocytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 263M Nov 12 07:06 human_enterocytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  82M Nov 12 07:11 macaque_enterocytes.hg38.cov.bw
# \n📂 BigWig files for Eosinophils:
# total 69M
# -rw-r----- 1 jjanssens jjanssens-group 13M Nov 12 07:11 bonobo_eosinophils.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 56M Nov 12 07:11 gorilla_eosinophils.hg38.cov.bw
# \n📂 BigWig files for Goblet-like_cells:
# total 0
# \n📂 BigWig files for Goblet_cells:
# total 1.1G
# -rw-r----- 1 jjanssens jjanssens-group 112M Nov 12 07:16 bonobo_goblet_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 164M Nov 12 07:16 chimpanzee_goblet_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 237M Nov 12 07:15 gorilla_goblet_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 449M Nov 12 07:14 human_goblet_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 121M Nov 12 07:17 macaque_goblet_cells.hg38.cov.bw
# \n📂 BigWig files for ICCs:
# total 98M
# -rw-r----- 1 jjanssens jjanssens-group 4.6M Nov 12 07:17 bonobo_iccs.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  12M Nov 12 07:17 chimpanzee_iccs.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  25M Nov 12 07:17 gorilla_iccs.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  48M Nov 12 07:17 human_iccs.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 9.1M Nov 12 07:17 macaque_iccs.hg38.cov.bw
# \n📂 BigWig files for ILCs:
# total 12M
# -rw-r----- 1 jjanssens jjanssens-group 12M Nov 12 07:17 human_ilcs.hg38.cov.bw
# \n📂 BigWig files for Lymphatic_ECs:
# total 405M
# -rw-r----- 1 jjanssens jjanssens-group  59M Nov 12 07:19 bonobo_lymphatic_ecs.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  77M Nov 12 07:19 chimpanzee_lymphatic_ecs.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 114M Nov 12 07:18 gorilla_lymphatic_ecs.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  83M Nov 12 07:18 human_lymphatic_ecs.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  71M Nov 12 07:19 macaque_lymphatic_ecs.hg38.cov.bw
# \n📂 BigWig files for MARCO+_Lymphatic_ECs:
# total 25M
# -rw-r----- 1 jjanssens jjanssens-group 25M Nov 12 07:19 bonobo_marco+_lymphatic_ecs.hg38.cov.bw
# \n📂 BigWig files for MUC6+_cells:
# total 319M
# -rw-r----- 1 jjanssens jjanssens-group 208M Nov 12 07:21 bonobo_muc6+_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  56M Nov 12 07:20 chimpanzee_muc6+_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  55M Nov 12 07:20 human_muc6+_cells.hg38.cov.bw
# \n📂 BigWig files for Macrophages:
# total 1.1G
# -rw-r----- 1 jjanssens jjanssens-group 176M Nov 12 07:25 bonobo_macrophages.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 221M Nov 12 07:24 chimpanzee_macrophages.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 279M Nov 12 07:23 gorilla_macrophages.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 265M Nov 12 07:22 human_macrophages.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 114M Nov 12 07:26 macaque_macrophages.hg38.cov.bw
# \n📂 BigWig files for Mast_cells:
# total 234M
# -rw-r----- 1 jjanssens jjanssens-group 35M Nov 12 07:27 bonobo_mast_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 39M Nov 12 07:26 chimpanzee_mast_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 92M Nov 12 07:26 gorilla_mast_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 68M Nov 12 07:26 human_mast_cells.hg38.cov.bw
# \n📂 BigWig files for Mesothelial_cells:
# total 250M
# -rw-r----- 1 jjanssens jjanssens-group  40M Nov 12 07:28 bonobo_mesothelial_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  34M Nov 12 07:27 chimpanzee_mesothelial_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 147M Nov 12 07:27 gorilla_mesothelial_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  29M Nov 12 07:28 macaque_mesothelial_cells.hg38.cov.bw
# \n📂 BigWig files for Monocytes:
# total 145M
# -rw-r----- 1 jjanssens jjanssens-group 28M Nov 12 07:28 bonobo_monocytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 84M Nov 12 07:28 chimpanzee_monocytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 15M Nov 12 07:28 human_monocytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 19M Nov 12 07:29 macaque_monocytes.hg38.cov.bw
# \n📂 BigWig files for Myofibroblasts:
# total 195M
# -rw-r----- 1 jjanssens jjanssens-group 37M Nov 12 07:29 bonobo_myofibroblasts.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 30M Nov 12 07:29 chimpanzee_myofibroblasts.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 33M Nov 12 07:29 gorilla_myofibroblasts.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 83M Nov 12 07:29 human_myofibroblasts.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 13M Nov 12 07:30 macaque_myofibroblasts.hg38.cov.bw
# \n📂 BigWig files for Naive_B_cells:
# total 725M
# -rw-r----- 1 jjanssens jjanssens-group 280M Nov 12 07:32 bonobo_naive_b_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 199M Nov 12 07:31 chimpanzee_naive_b_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  75M Nov 12 07:30 gorilla_naive_b_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  72M Nov 12 07:30 human_naive_b_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  99M Nov 12 07:33 macaque_naive_b_cells.hg38.cov.bw
# \n📂 BigWig files for Neutrophils:
# total 188M
# -rw-r----- 1 jjanssens jjanssens-group  20M Nov 12 07:34 bonobo_neutrophils.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 167M Nov 12 07:34 gorilla_neutrophils.hg38.cov.bw
# \n📂 BigWig files for Paneth_cells:
# total 164M
# -rw-r----- 1 jjanssens jjanssens-group  46M Nov 12 07:34 bonobo_paneth_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  59M Nov 12 07:34 chimpanzee_paneth_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  42M Nov 12 07:34 gorilla_paneth_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 9.4M Nov 12 07:34 human_paneth_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 8.3M Nov 12 07:35 macaque_paneth_cells.hg38.cov.bw
# \n📂 BigWig files for Pericytes:
# total 212M
# -rw-r----- 1 jjanssens jjanssens-group  46M Nov 12 07:36 bonobo_pericytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  24M Nov 12 07:35 chimpanzee_pericytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  53M Nov 12 07:35 gorilla_pericytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  84M Nov 12 07:35 human_pericytes.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 5.4M Nov 12 07:36 macaque_pericytes.hg38.cov.bw
# \n📂 BigWig files for Plasma_B_cells:
# total 1.4G
# -rw-r----- 1 jjanssens jjanssens-group 378M Nov 12 07:42 bonobo_plasma_b_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 379M Nov 12 07:40 chimpanzee_plasma_b_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 337M Nov 12 07:38 gorilla_plasma_b_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 197M Nov 12 07:37 human_plasma_b_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  38M Nov 12 07:42 macaque_plasma_b_cells.hg38.cov.bw
# \n📂 BigWig files for RBP2_high_cells:
# total 0
# \n📂 BigWig files for Specialized_Fibroblasts_ADAMTS16+:
# total 26M
# -rw-r----- 1 jjanssens jjanssens-group 26M Nov 12 07:42 gorilla_specialized_fibroblasts_adamts16+.hg38.cov.bw
# \n📂 BigWig files for Specialized_Fibroblasts_KCNN3+:
# total 585M
# -rw-r----- 1 jjanssens jjanssens-group  36M Nov 12 07:45 bonobo_specialized_fibroblasts_kcnn3+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  87M Nov 12 07:45 chimpanzee_specialized_fibroblasts_kcnn3+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 222M Nov 12 07:44 gorilla_specialized_fibroblasts_kcnn3+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 216M Nov 12 07:43 human_specialized_fibroblasts_kcnn3+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  24M Nov 12 07:45 macaque_specialized_fibroblasts_kcnn3+.hg38.cov.bw
# \n📂 BigWig files for Specialized_Fibroblasts_PCDH9+:
# total 9.9M
# -rw-r----- 1 jjanssens jjanssens-group 9.9M Nov 12 07:45 macaque_specialized_fibroblasts_pcdh9+.hg38.cov.bw
# \n📂 BigWig files for Specialized_Fibroblasts_RALYL+:
# total 63M
# -rw-r----- 1 jjanssens jjanssens-group 33M Nov 12 07:45 chimpanzee_specialized_fibroblasts_ralyl+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 20M Nov 12 07:45 gorilla_specialized_fibroblasts_ralyl+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 11M Nov 12 07:46 macaque_specialized_fibroblasts_ralyl+.hg38.cov.bw
# \n📂 BigWig files for Specialized_Fibroblasts_RSPO2_3+:
# total 254M
# -rw-r----- 1 jjanssens jjanssens-group  21M Nov 12 07:47 bonobo_specialized_fibroblasts_rspo2_3+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  56M Nov 12 07:46 chimpanzee_specialized_fibroblasts_rspo2_3+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  40M Nov 12 07:46 gorilla_specialized_fibroblasts_rspo2_3+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 102M Nov 12 07:46 human_specialized_fibroblasts_rspo2_3+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  36M Nov 12 07:47 macaque_specialized_fibroblasts_rspo2_3+.hg38.cov.bw
# \n📂 BigWig files for Specialized_Fibroblasts_RSPO3+_only:
# total 586M
# -rw-r----- 1 jjanssens jjanssens-group  78M Nov 12 07:49 bonobo_specialized_fibroblasts_rspo3+_only.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  76M Nov 12 07:49 chimpanzee_specialized_fibroblasts_rspo3+_only.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 205M Nov 12 07:49 gorilla_specialized_fibroblasts_rspo3+_only.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 193M Nov 12 07:48 human_specialized_fibroblasts_rspo3+_only.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  33M Nov 12 07:49 macaque_specialized_fibroblasts_rspo3+_only.hg38.cov.bw
# \n📂 BigWig files for Specialized_Fibroblasts_SYNM+:
# total 1.6G
# -rw-r----- 1 jjanssens jjanssens-group  87M Nov 12 07:57 bonobo_specialized_fibroblasts_synm+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 274M Nov 12 07:57 chimpanzee_specialized_fibroblasts_synm+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 509M Nov 12 07:56 gorilla_specialized_fibroblasts_synm+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 632M Nov 12 07:53 human_specialized_fibroblasts_synm+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  37M Nov 12 07:57 macaque_specialized_fibroblasts_synm+.hg38.cov.bw
# \n📂 BigWig files for Specialized_Fibroblasts_VCAM1+:
# total 128M
# -rw-r----- 1 jjanssens jjanssens-group 44M Nov 12 07:58 bonobo_specialized_fibroblasts_vcam1+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 45M Nov 12 07:58 chimpanzee_specialized_fibroblasts_vcam1+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 20M Nov 12 07:58 human_specialized_fibroblasts_vcam1+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 20M Nov 12 07:58 macaque_specialized_fibroblasts_vcam1+.hg38.cov.bw
# \n📂 BigWig files for Stem_cells:
# total 570M
# -rw-r----- 1 jjanssens jjanssens-group  51M Nov 12 08:00 bonobo_stem_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 152M Nov 12 08:00 chimpanzee_stem_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  92M Nov 12 08:00 gorilla_stem_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 224M Nov 12 07:59 human_stem_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  51M Nov 12 08:01 macaque_stem_cells.hg38.cov.bw
# \n📂 BigWig files for TA_cells:
# total 2.0G
# -rw-r----- 1 jjanssens jjanssens-group 473M Nov 12 08:09 bonobo_ta_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 427M Nov 12 08:07 chimpanzee_ta_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 550M Nov 12 08:05 gorilla_ta_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  15K Nov 11 11:40 human_ta_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 540M Nov 12 08:12 macaque_ta_cells.hg38.cov.bw
# \n📂 BigWig files for T_cells:
# total 1.9G
# -rw-r----- 1 jjanssens jjanssens-group 515M Nov 12 08:21 bonobo_t_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 598M Nov 12 08:19 chimpanzee_t_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 400M Nov 12 08:15 gorilla_t_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 263M Nov 12 08:13 human_t_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 146M Nov 12 08:22 macaque_t_cells.hg38.cov.bw
# \n📂 BigWig files for Tuft_cells:
# total 109M
# -rw-r----- 1 jjanssens jjanssens-group 7.2M Nov 12 08:23 bonobo_tuft_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  36M Nov 12 08:22 chimpanzee_tuft_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 5.9M Nov 12 08:22 gorilla_tuft_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  46M Nov 12 08:22 human_tuft_cells.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group  14M Nov 12 08:23 macaque_tuft_cells.hg38.cov.bw
# \n📂 BigWig files for Villus_Fibroblasts_WNT5B+:
# total 214M
# -rw-r----- 1 jjanssens jjanssens-group 19M Nov 12 08:24 bonobo_villus_fibroblasts_wnt5b+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 46M Nov 12 08:23 chimpanzee_villus_fibroblasts_wnt5b+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 40M Nov 12 08:23 gorilla_villus_fibroblasts_wnt5b+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 89M Nov 12 08:23 human_villus_fibroblasts_wnt5b+.hg38.cov.bw
# -rw-r----- 1 jjanssens jjanssens-group 21M Nov 12 08:24 macaque_villus_fibroblasts_wnt5b+.hg38.cov.bw

# %% [markdown]
# ---
# ## Summary
#
# ### Output Structure
#
# ```
# fragment_files/
# └── enterocytes/
#     ├── human_enterocytes.fragments.tsv.gz
#     ├── gorilla_enterocytes.fragments.tsv.gz
#     ├── chimpanzee_enterocytes.fragments.tsv.gz
#     ├── bonobo_enterocytes.fragments.tsv.gz
#     ├── macaque_enterocytes.fragments.tsv.gz
#     └── marmoset_enterocytes.fragments.tsv.gz
#
# lifted_fragments/
# └── enterocytes/
#     ├── human_enterocytes.hg38.fragments.tsv.gz
#     ├── gorilla_enterocytes.hg38.fragments_par.tsv.gz
#     ├── chimpanzee_enterocytes.hg38.fragments_par.tsv.gz
#     ├── bonobo_enterocytes.hg38.fragments_par.tsv.gz
#     ├── macaque_enterocytes.hg38.fragments_par.tsv.gz
#     └── marmoset_enterocytes.hg38.fragments_par.tsv.gz
#
# bigwigs/
# └── enterocytes/
#     ├── human_enterocytes.hg38.cov.bw
#     ├── gorilla_enterocytes.hg38.cov.bw
#     ├── chimpanzee_enterocytes.hg38.cov.bw
#     ├── bonobo_enterocytes.hg38.cov.bw
#     ├── macaque_enterocytes.hg38.cov.bw
#     └── marmoset_enterocytes.hg38.cov.bw
# ```
#
# ### Processing Notes
#
# - **Human**: No liftover needed (already hg38), direct symlink created
# - **Standard species** (Gorilla, Chimpanzee, Bonobo, Macaque): Single-step liftover with 30 CPUs
# - **Marmoset**: Two-step liftover (calJac1 → calJac4 → hg38) with 30 CPUs
# - All outputs organized by cell type for easy access and management
# - BigWig files use normalized coverage (`-n` flag) for cross-sample comparison
